# %%
import requests
import numpy as np
from config import *
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import os
import json

from dateutil.relativedelta import relativedelta
from docopt import docopt #해당 모듈을 어떻게 쓸지 자동으로 알려 줌
from warnings import filterwarnings

filterwarnings('ignore')

rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# font_path = "C:/Windows/Fonts/malgun.ttf"
# font = font_manager.FontProperties(fname=font_path).get_name()
# rc('font', family=font)
# plt.rcParams['axes.unicode_minus'] = False

# %%
def df_plotting(df, title='Insert Title'):

    column_idx = df.columns.to_list()
    time_idx = df.index.to_list()

    plt.figure(figsize=(20,12), facecolor='w')
    
    color_sequence = ['b', 'r', 'yellow', 'g', 'm', 'purple', "navy", 'orange', 'pink']

    for idx, i in enumerate(column_idx):
        plt.plot(time_idx, df[i], color=color_sequence[idx], label=i, linewidth=1.2)

    plt.title(title, size=30)
    plt.legend(fontsize=20)
    plt.xticks(fontsize=15, rotation=30)
    plt.yticks(fontsize=15)
    plt.show()

# %%
def daily_news_df(date_from, date_to):
    
    date_from = dt.datetime.strptime(date_from, '%Y-%m-%d').isoformat()[0:10]
    date_to = dt.datetime.strptime(date_to, '%Y-%m-%d').isoformat()[0:10]

    #date_interval = list(pd.date_range(dt.datetime.strptime(date_from, '%Y-%m-%d'), dt.datetime.strptime(date_to, '%Y-%m-%d'), freq='d'))  

    url = f"{ELASTIC_SEARCH_URL}/news/_search"

    query_day = {
        "size": 0,
            "query":{
                "range":{
                "created_at": {
                    "gte": date_from,
                    "lte": date_to
                    }
                }
            },
            "aggs": {
                "group_by_date":{
                "date_histogram": {
                    "field": "created_at",
                    "interval": "day"
                }
            }
        }
    }

    headers = {
        'Content-Type' : 'application/json'
    }

    resp = requests.get(
        url,
        data=json.dumps(query_day),
        headers=headers,
        auth= ELASTIC_SEARCH_AUTH
    )

    data = resp.json()

    daily = data['aggregations']['group_by_date']['buckets']
    df_daily = pd.DataFrame(data = daily)[['key_as_string', 'doc_count']]
    df_daily = df_daily.rename(columns={"key_as_string" : "date"})
    df_daily['date'] = pd.to_datetime(df_daily['date'])
    df_daily = df_daily.set_index('date')

    return df_daily

# %%
df = daily_news_df("2022-05-01", "2022-05-31")

# %%
df_plotting(df, "뉴스 개수")

# %%
df
# Out:
#                            doc_count
# date
# 2022-05-01 00:00:00+00:00       1974
# 2022-05-02 00:00:00+00:00       5806
# 2022-05-03 00:00:00+00:00       5984
# 2022-05-04 00:00:00+00:00       5335
# 2022-05-05 00:00:00+00:00       1963
# 2022-05-06 00:00:00+00:00       3282
# 2022-05-07 00:00:00+00:00        657
# 2022-05-08 00:00:00+00:00       1596
# 2022-05-09 00:00:00+00:00       5154
# 2022-05-10 00:00:00+00:00       4875
# 2022-05-11 00:00:00+00:00       5791
# 2022-05-12 00:00:00+00:00       6256
# 2022-05-13 00:00:00+00:00       4633
# 2022-05-14 00:00:00+00:00        681
# 2022-05-15 00:00:00+00:00       1893
# 2022-05-16 00:00:00+00:00       5807
# 2022-05-17 00:00:00+00:00       5640
# 2022-05-18 00:00:00+00:00       5850
# 2022-05-19 00:00:00+00:00       5351
# 2022-05-20 00:00:00+00:00       3998
# 2022-05-21 00:00:00+00:00        876
# 2022-05-22 00:00:00+00:00       1871
# 2022-05-23 00:00:00+00:00       5014
# 2022-05-24 00:00:00+00:00       5224
# 2022-05-25 00:00:00+00:00       5675
# 2022-05-26 00:00:00+00:00       6516
# 2022-05-27 00:00:00+00:00       4108
# 2022-05-28 00:00:00+00:00        642
# 2022-05-29 00:00:00+00:00       1874
# 2022-05-30 00:00:00+00:00       6087
# 2022-05-31 00:00:00+00:00       5381

# %% [markdown]
# # 2. Top5 언론사 리스트 변수로 받아 각 날짜 별로 언론사 기사 갯수 time-series chart 출력

# %% [markdown]
# ## Top5 언론사

# %%
def top_publisher(num_of_publisher, date_from, date_to):
    
    date_from = dt.datetime.strptime(date_from, '%Y-%m-%d').isoformat()[0:10]
    date_to = dt.datetime.strptime(date_to, '%Y-%m-%d').isoformat()[0:10]

    url = f"{ELASTIC_SEARCH_URL}/news/_search"

    query_publisher = {
    "size": 0,
        "query":{
            "range":{
                "created_at": {
                    "gte": date_from,
                    "lte": date_to
                    }
                }
            },
    "aggs": {
        "group_by_publisher":{
            "terms": {
                "field": "publisher.keyword",
                "size": num_of_publisher
                }
            }
        }
    }

    headers = {
        'Content-Type' : 'application/json'
    }

    resp = requests.get(
        url,
        data=json.dumps(query_publisher),
        headers=headers,
        auth= ELASTIC_SEARCH_AUTH
    )

    data = resp.json()

    dict = data['aggregations']['group_by_publisher']['buckets']

    df = pd.DataFrame(data=dict)

    # publisher_list = []
    # for i in range(len(dict)):
    #     publisher_list.append(dict[i]['key'])

    return df['key'].to_list()

# %%
top_publisher(5, "2022-05-01", "2022-05-31")
# Out:
# ['뉴스1', '뉴시스', '연합뉴스', '이데일리', '파이낸셜뉴스']

# %%
def publisher_daily_news_trend (publisher_list, date_from, date_to):
    
    time_idx = daily_news_df(date_from, date_to).index.to_list()

    date_from = dt.datetime.strptime(date_from, '%Y-%m-%d').isoformat()[0:10]
    date_to = dt.datetime.strptime(date_to, '%Y-%m-%d').isoformat()[0:10]

    df = pd.DataFrame(index=time_idx)

    url = f"{ELASTIC_SEARCH_URL}/news/_search"

    headers = {
    'Content-Type' : 'application/json'
    }


    for keyword in publisher_list:
        query = {
            "size": 0,
            "query":{
                "range":{
                    "created_at": {
                        "gte": date_from,
                        "lte": date_to
                        }
                    }
                },
                "aggs": {
                    "group_by_date":{
                        "date_histogram": {
                            "field": "created_at",
                            "interval": "day"
                        }
                    }
                },
                "query":{
                    "match":{
                    "publisher": keyword
                    }
                }
        }
        
        resp = requests.get(
            url,
            data=json.dumps(query),
            headers=headers,
            auth= ELASTIC_SEARCH_AUTH
        )

        data = resp.json()
        data = data['aggregations']['group_by_date']['buckets']
        df_tmp = pd.DataFrame(data = data)[['key_as_string', 'doc_count']]
        df_tmp = df_tmp.rename(columns={"key_as_string" : "date"})
        df_tmp['date'] = pd.to_datetime(df_tmp['date'])
        df_tmp = df_tmp.set_index('date')

        df[keyword] = df_tmp['doc_count']


    return df

# %%
publisher_daily_news_trend(top_publisher(5, "2022-05-01", "2022-05-31"), "2022-05-01", "2022-05-31")
# Out:
#                            뉴스1  뉴시스  연합뉴스  이데일리  파이낸셜뉴스
# 2022-05-01 00:00:00+00:00  217  161   178   136     128
# 2022-05-02 00:00:00+00:00  471  500   406   443     353
# 2022-05-03 00:00:00+00:00  528  580   461   494     316
# 2022-05-04 00:00:00+00:00  501  403   403   400     293
# 2022-05-05 00:00:00+00:00  116  128   162   100      99
# 2022-05-06 00:00:00+00:00  279  284   263   278     123
# 2022-05-07 00:00:00+00:00   45   50    39    48      26
# 2022-05-08 00:00:00+00:00  104  103   125    89     110
# 2022-05-09 00:00:00+00:00  446  420   378   385     288
# 2022-05-10 00:00:00+00:00  390  393   375   414     287
# 2022-05-11 00:00:00+00:00  482  433   499   404     326
# 2022-05-12 00:00:00+00:00  521  628   549   446     309
# 2022-05-13 00:00:00+00:00  370  354   381   370     194
# 2022-05-14 00:00:00+00:00   45   45    33    46      32
# 2022-05-15 00:00:00+00:00  186  147   200   109     114
# 2022-05-16 00:00:00+00:00  480  452   496   453     350
# 2022-05-17 00:00:00+00:00  414  462   483   435     284
# 2022-05-18 00:00:00+00:00  498  525   507   514     298
# 2022-05-19 00:00:00+00:00  479  430   457   375     284
# 2022-05-20 00:00:00+00:00  394  329   296   291     144
# 2022-05-21 00:00:00+00:00   54   94    69    93      33
# 2022-05-22 00:00:00+00:00  119  136   245   122     105
# 2022-05-23 00:00:00+00:00  430  385   376   363     287
# 2022-05-24 00:00:00+00:00  422  537   583   373     271
# 2022-05-25 00:00:00+00:00  514  539   479   368     307
# 2022-05-26 00:00:00+00:00  555  544   578   457     294
# 2022-05-27 00:00:00+00:00  378  286   307   346     153
# 2022-05-28 00:00:00+00:00   30   55    53    61      25
# 2022-05-29 00:00:00+00:00  188  122   231    94     115
# 2022-05-30 00:00:00+00:00  556  511   495   405     345
# 2022-05-31 00:00:00+00:00  432  520   446   389     277

# %%
df_plotting(publisher_daily_news_trend(top_publisher(5, "2022-05-01", "2022-05-31"), "2022-05-01", "2022-05-31"),"Top 5 daily news")

# %% [markdown]
# # 3. 키워드 리스트를 변수로 받아 키워드별 일별 기사 갯수 & 비율 출력

# %%
def keyword_daily_news_trend (keyword_list, date_from, date_to):

    time_idx = daily_news_df(date_from, date_to).index.to_list()

    date_from = dt.datetime.strptime(date_from, '%Y-%m-%d').isoformat()[0:10]
    date_to = dt.datetime.strptime(date_to, '%Y-%m-%d').isoformat()[0:10]

    df = pd.DataFrame(index=time_idx)

    url = f"{ELASTIC_SEARCH_URL}/news/_search"

    headers = {
    'Content-Type' : 'application/json'
    }


    for keyword in keyword_list:
        query = {
                "size": 0,
                    "query":{
                        "range":{
                        "created_at": {
                            "gte": date_from,
                            "lte": date_to
                            }
                        }
                },
                "aggs": {
                    "group_by_date":{
                        "date_histogram": {
                            "field": "created_at",
                            "interval": "day"
                        }
                    }
                },
                "query":{
                    "match":{
                    "body": keyword
                    }
                }
            }

        resp = requests.get(
            url,
            data=json.dumps(query),
            headers=headers,
            auth= ELASTIC_SEARCH_AUTH
        )

        data = resp.json()
        data = data['aggregations']['group_by_date']['buckets']
        df_tmp = pd.DataFrame(data = data)[['key_as_string', 'doc_count']]
        df_tmp = df_tmp.rename(columns={"key_as_string" : "date"})
        df_tmp['date'] = pd.to_datetime(df_tmp['date'])
        df_tmp = df_tmp.set_index('date')

        df[keyword] = df_tmp['doc_count']

    
    df = df.fillna(0)

    return df

# %%
df_plotting(keyword_daily_news_trend(['전쟁', '인플레이션', '암호화폐'], "2022-05-01", "2022-05-31"), "Keyword News Trend")

# %%
keyword_daily_news_trend(['전쟁', '인플레이션', '암호화폐'], "2022-05-01", "2022-05-31")
# Out:
#                             전쟁  인플레이션  암호화폐
# 2022-05-01 00:00:00+00:00   56     59    10
# 2022-05-02 00:00:00+00:00  107    128    23
# 2022-05-03 00:00:00+00:00  110    151    47
# 2022-05-04 00:00:00+00:00   84    131    19
# 2022-05-05 00:00:00+00:00   90    148    11
# 2022-05-06 00:00:00+00:00   69    133    39
# 2022-05-07 00:00:00+00:00   28     38    16
# 2022-05-08 00:00:00+00:00   47     89    13
# 2022-05-09 00:00:00+00:00   78    182    58
# 2022-05-10 00:00:00+00:00   97    247    66
# 2022-05-11 00:00:00+00:00  109    195    40
# 2022-05-12 00:00:00+00:00  113    301   121
# 2022-05-13 00:00:00+00:00   63    191   123
# 2022-05-14 00:00:00+00:00   24     34    38
# 2022-05-15 00:00:00+00:00   53     72    49
# 2022-05-16 00:00:00+00:00  116    129    91
# 2022-05-17 00:00:00+00:00  125    182   112
# 2022-05-18 00:00:00+00:00  156    154    72
# 2022-05-19 00:00:00+00:00   90    249   102
# 2022-05-20 00:00:00+00:00   62    120    42
# 2022-05-21 00:00:00+00:00   27     28    16
# 2022-05-22 00:00:00+00:00   28     76    28
# 2022-05-23 00:00:00+00:00   84     80    33
# 2022-05-24 00:00:00+00:00   61     98    59
# 2022-05-25 00:00:00+00:00   85    155    61
# 2022-05-26 00:00:00+00:00  130    299    62
# 2022-05-27 00:00:00+00:00   67     89    33
# 2022-05-28 00:00:00+00:00   16     40    13
# 2022-05-29 00:00:00+00:00   34     67    10
# 2022-05-30 00:00:00+00:00   78    177    37
# 2022-05-31 00:00:00+00:00   77    147    48

# %% [markdown]
# # 4. 날짜별로 뉴스 Title 크롤링해서 리스트로 정리

# %%
def fetch_news_docs(date_from, date_to, page):
    
    date_from = date_from.isoformat()[0:10]
    date_to = date_to.isoformat()[0:10]

    query = {
        "query": {
            "range":{
                "created_at": {
                    "gte": date_from,
                    "lte": date_to
                }
            }
        },
        "size": 10,
        "from": page * 10
    }

    headers = {
        'Content-Type': 'application/json'
    }

    resp = requests.get(
        f'{ELASTIC_SEARCH_URL}/news/_search',
        headers = headers,
        data = json.dumps(query),
        auth = ELASTIC_SEARCH_AUTH
    )

    assert resp.status_code == 200

    data = json.loads(resp.text)
    hits = data['hits']['hits']

    return hits

def get_titles(hits):

    return hits['_source']['title']

def download_total_title (date_from, date_to):

    date_from = dt.datetime.strptime(date_from, '%Y-%m-%d').isoformat()[0:10]
    date_to = dt.datetime.strptime(date_to, '%Y-%m-%d').isoformat()[0:10]

    date_interval = list(pd.date_range(date_from, date_to, freq='d'))

    # print("Downloading data from OpenSearch server")

    total_title_list = []

    for i in range(len(date_interval)):

        str_date = date_interval[i].strftime('%Y-%m-%d')

        # print(f"{str_date} Start!")

        daily_title_list = []

        start_date = date_interval[i]
        end_date = date_interval[i] + relativedelta(days=1)

        for page in range(1000):

#            print('.', end='', flush=True)

            hits = fetch_news_docs(start_date, end_date, page)

            if len(hits) == 0:
                break

            for doc in hits:
            
                daily_title_list.append(get_titles(doc))

        total_title_list.append(daily_title_list)

        # print("***" + str_date + "End!" + "***")

    # print("Daily Data end!")

    return total_title_list

def total_title_show (total_title_list, date_from, date_to):

    date_from = dt.datetime.strptime(date_from, '%Y-%m-%d').isoformat()[0:10]
    date_to = dt.datetime.strptime(date_to, '%Y-%m-%d').isoformat()[0:10]

    date_interval = list(pd.date_range(date_from, date_to, freq='d'))

    for i in range(len(date_interval)):

        str_date = date_interval[i].strftime('%Y-%m-%d')

        print(str_date)
        print(total_title_list[i] + '\n')

    #return date_interval

def txt_title_save (total_title_list, date_from, date_to):

    date_from = dt.datetime.strptime(date_from, '%Y-%m-%d').isoformat()[0:10]
    date_to = dt.datetime.strptime(date_to, '%Y-%m-%d').isoformat()[0:10]

    date_interval = list(pd.date_range(date_from, date_to, freq='d'))

    with open('title_list_allday.txt','w',encoding='UTF-8') as f:

        for i in range(len(total_title_list)):
        
            str_date = date_interval[i].strftime('%Y-%m-%d')

            f.write('\n' + '[' + str_date + ']' + '\n\n')
        
            for titles in total_title_list[i]:

                f.write(titles + '\n')

# %%
def fetch_news_docs(date_from, date_to, page):
    
    date_from = date_from.isoformat()[0:10]
    date_to = date_to.isoformat()[0:10]

    query = {
        "query": {
            "range":{
                "created_at": {
                    "gte": date_from,
                    "lte": date_to
                }
            }
        },
        "size": 10,
        "from": page * 10
    }

    headers = {
        'Content-Type': 'application/json'
    }

    resp = requests.get(
        f'{ELASTIC_SEARCH_URL}/news/_search',
        headers = headers,
        data = json.dumps(query),
        auth = ELASTIC_SEARCH_AUTH
    )

    assert resp.status_code == 200

    data = json.loads(resp.text)
    hits = data['hits']['hits']

    return hits

def get_titles(hits):

    return hits['_source']['title']

def download_total_title (date_from, date_to):

    date_from = dt.datetime.strptime(date_from, '%Y-%m-%d').isoformat()[0:10]
    date_to = dt.datetime.strptime(date_to, '%Y-%m-%d').isoformat()[0:10]

    date_interval = list(pd.date_range(date_from, date_to, freq='d'))

    # print("Downloading data from OpenSearch server")

    total_title_list = []

    for i in range(len(date_interval)):

        str_date = date_interval[i].strftime('%Y-%m-%d')

        # print(f"{str_date} Start!")

        daily_title_list = []

        start_date = date_interval[i]
        end_date = date_interval[i] + relativedelta(days=1)

        for page in range(1000):

#            print('.', end='', flush=True)

            hits = fetch_news_docs(start_date, end_date, page)

            if len(hits) == 0:
                break

            for doc in hits:
            
                daily_title_list.append(get_titles(doc))

        total_title_list.append(daily_title_list)

        # print("***" + str_date + "End!" + "***")

    # print("Daily Data end!")

    return total_title_list

def total_title_show (total_title_list, date_from, date_to):

    date_from = dt.datetime.strptime(date_from, '%Y-%m-%d').isoformat()[0:10]
    date_to = dt.datetime.strptime(date_to, '%Y-%m-%d').isoformat()[0:10]

    date_interval = list(pd.date_range(date_from, date_to, freq='d'))

    for i in range(len(date_interval)):

        str_date = date_interval[i].strftime('%Y-%m-%d')

        print(str_date)
        print(total_title_list[i] + '\n')

    #return date_interval

def txt_title_save (total_title_list, date_from, date_to):

    date_from = dt.datetime.strptime(date_from, '%Y-%m-%d').isoformat()[0:10]
    date_to = dt.datetime.strptime(date_to, '%Y-%m-%d').isoformat()[0:10]

    date_interval = list(pd.date_range(date_from, date_to, freq='d'))

    with open('title_list_allday.txt','w',encoding='UTF-8') as f:

        for i in range(len(total_title_list)):
        
            str_date = date_interval[i].strftime('%Y-%m-%d')

            f.write('\n' + '[' + str_date + ']' + '\n\n')
        
            for titles in total_title_list[i]:

                f.write(titles + '\n')

# %%
#daily_news_title = download_total_title('2022-05-01', '2022-05-31')

# %%
#daily_news_title

# %%
#txt_title_save(daily_news_title, '2022-05-01', '2022-05-31')

# %%
def fetch_news_docs_keyword(date_from, date_to, page, keyword):
    
    date_from = date_from.isoformat()[0:10]
    date_to = date_to.isoformat()[0:10]

    query = {
        "query": {
            "bool": {
                "must":[
                    {
                        "match":{
                            "body": keyword
                        }
                    },
                    {
                    "range":{
                        "created_at": {
                            "gte": date_from,
                            "lt": date_to
                            }
                        }
                    }
                ]
            },
        },
        "size": 10,
        "from": page * 10
    }

    headers = {
        'Content-Type': 'application/json'
    }

    resp = requests.get(
        f'{ELASTIC_SEARCH_URL}/news/_search',
        headers = headers,
        data = json.dumps(query),
        auth = ELASTIC_SEARCH_AUTH
    )

    assert resp.status_code == 200

    data = json.loads(resp.text)
    hits = data['hits']['hits']

    return hits

def get_bodies(hits):

    return hits['_source']['body']


def download_total_title_keyword (date_from, date_to, keyword):

    date_from = dt.datetime.strptime(date_from, '%Y-%m-%d').isoformat()[0:10]
    date_to = dt.datetime.strptime(date_to, '%Y-%m-%d').isoformat()[0:10]

    date_interval = list(pd.date_range(date_from, date_to, freq='d'))

    # print("Downloading data from OpenSearch server")

    total_title_list = []

    for i in range(len(date_interval)):

        str_date = date_interval[i].strftime('%Y-%m-%d')

        # print(f"{str_date} Start!")

        daily_title_list = []

        start_date = date_interval[i]
        end_date = date_interval[i] + relativedelta(days=1)

        for page in range(1000):

#            print('.', end='', flush=True)

            hits = fetch_news_docs_keyword(start_date, end_date, page, keyword)

            if len(hits) == 0:
                break

            for doc in hits:
            
                daily_title_list.append(get_titles(doc))

        total_title_list.append(daily_title_list)

        # print("***" + str_date + "End!" + "***")

    # print("Daily Data end!")

    return total_title_list

def download_total_bodies_keyword (date_from, date_to, keyword):

    date_from = dt.datetime.strptime(date_from, '%Y-%m-%d').isoformat()[0:10]
    date_to = dt.datetime.strptime(date_to, '%Y-%m-%d').isoformat()[0:10]

    date_interval = list(pd.date_range(date_from, date_to, freq='d'))

    # print("Downloading data from OpenSearch server")

    total_title_list = []

    for i in range(len(date_interval)):

        str_date = date_interval[i].strftime('%Y-%m-%d')

        # print(f"{str_date} Start!")

        daily_title_list = []

        start_date = date_interval[i]
        end_date = date_interval[i] + relativedelta(days=1)

        for page in range(1000):

#            print('.', end='', flush=True)

            hits = fetch_news_docs_keyword(start_date, end_date, page, keyword)

            if len(hits) == 0:
                break

            for doc in hits:
            
                daily_title_list.append(get_bodies(doc))

        total_title_list.append(daily_title_list)

        # print("***" + str_date + "End!" + "***")

    # print("Daily Data end!")

    return total_title_list

# %%
key_list = download_total_title_keyword('2022-05-01', '2022-05-01', "삼성전자")

# %%
key_list
# Out:
# [['삼성전자 상반기 C랩 스핀오프 론칭데이',
#   "'성공을 기원합니다'",
#   "'필로토' 창업자 응원하는 박학규 사장",
#   '삼성전자, 상반기 C랩 스핀오프 론칭데이',
#   "삼성전자, '에듀테크' 관련 C랩 과제 2개 스타트업 창업 지원",
#   "삼성전자, 에버랜드서 3년만에 오프라인 '갤럭시 팬파티'",
#   '대-중소기업 임금 양극화 심한데…삼성전자 노조 “돈 더 달라” 몽니',
#   '웨이퍼 들었던 바이든, 삼성 반도체 공장 방문하나…기대감↑',
#   '삼성전자, AI 온라인 시험 감독 등 에듀테크 스타트업 창업 지원',
#   "삼성, 모바일 AP 점유율 '반토막'…파운드리도 18%서 정체",
#   'AI로 온라인 시험 부정 잡는다..삼성이 지원하는 사내벤처는?',
#   "삼성전자, hy·삼성카드와 '비스포크 큐커' 할인행사",
#   '"AI가 시험 감독"…삼성전자, 사내벤처 2곳 \'픽\'',
#   "삼성전자, hy와 함께 '우리집 전자레인지, 큐커로 교체' 캠페인",
#   "삼성전자, hy와 함께 '우리집 전자레인지, 큐커로 교체' 캠페인",
#   "삼성전자, hy와 함께 '우리집 전자레인지, 큐커로 교체' 캠페인",
#   "삼성전자, hy와 함께 '우리집 전자레인지, 큐커로 교체' 캠페인",
#   "삼성전자, '에듀테크' 관련 C랩 과제 2개 스타트업 창업 지원",
#   "삼성전자, '에듀테크' 관련 C랩 과제 2개 스타트업 창업 지원",
#   '韓 반도체, “공급망 재편서 살아남으려면 美 동맹 참여해야”',
#   '삼성전자, `우리집 전자레인지, 큐커로 교체해요` 2차 캠페인 진행…hy와 협업',
#   '‘지역화폐 지원’ 삼성페이, 지역경제 활성화 나선다',
#   "삼성전자 파운드리 출범 5년…공존하는 '기회와 위기'",
#   "삼성전자, '에듀테크' 관련 C랩 과제 2개 스타트업 창업 지원",
#   '"三電, 이재용 부회장 빈자리 크다"…커지는 사면복권 목소리',
#   '삼성전자, 에듀테크 관련 C랩 과제 2개 스타트업 창업 지원',
#   "에버랜드에 모인 '갤럭시 찐팬들'…갤S22 팬파티 현장 컴백 '성공적'",
#   "삼성전자-hy,  '우리집 전자레인지, 큐커로 교체' 캠페인",
#   '삼성전자-hy "비스포크 큐커 약정 구매하고 혜택 받아요"',
#   '우리 집 전자레인지, 비스포크 큐커로 바꿔볼까',
#   "'재벌 사면' MB 역대 최다…文, 이재용 '사법 족쇄' 결단은 [뉴스원샷]",
#   '가석방 신세에 갇힌 삼성…文 ‘이재용 사면’ 진짜 할까',
#   '“반도체망 2025년 재편… 한국, 美동맹 참여를”',
#   '바이든, 삼성 반도체공장 찾나… “미국 ‘반도체 동맹’에 참여 필요”',
#   '이재용 사면·尹정부 출범·바이든 평택 방문…삼성 운명이 갈린다',
#   "삼성 '2030 시스템반도체 1위' 선포 3년…점유율은 오히려 하락",
#   "'성공을 향해'",
#   "2000명 몰렸다…삼성전자 '갤럭시 팬파티' 성료",
#   '"거북목 고치는 AI"…삼성전자, 에듀테크 스타트업 2곳 스핀오프',
#   "삼성전자, hy와 '전자레인지, 큐커로 교체' 두번째 캠페인",
#   '"AI가 시험 감독"…삼성전자, \'에듀테크\' 관련 C랩 과제 2개 스타트업 창업 지원',
#   "'AI 캐릭터로 스마트기기 사용 습관 길러요'",
#   "'AI가 온라인 시험 관리 감독합니다'",
#   "삼성전자, hy·삼성카드와 '전자레인지 쿠커로 교체' 캠페인",
#   "삼성전자 '갤럭시 팬파티 522랜드' 피날레",
#   "AI가 아이 'TV 습관' 조절한다",
#   "삼성전자, hy와 함께 '우리집 전자레인지, 큐커로 교체' 캠페인",
#   "삼성전자, '갤럭시 팬파티 522랜드' 성황리에 진행",
#   "삼성전자, '갤럭시 팬파티 522랜드' 성황리에 진행",
#   "'갤럭시 팬파티 522랜드' 성황",
#   '삼성전자 “낡은 전자레인지, 5만원에 큐커로 바꾸세요”',
#   "'갤럭시 팬파티 522랜드' 성황",
#   '삼성전자, 3년 만에 오프라인 ‘갤럭시 팬파티’…팬덤 뭉쳤다',
#   '반도체 지각변동… 세계1위 삼성 흔들리나',
#   '"갤럭시 팬 2000명 한자리에"…\'522랜드\' 떴다',
#   '스마트폰 교육·시험 감독을 AI가?…삼성C랩 스타트업 ‘킥오프’',
#   '역대급 실적에도 위기론…M&A 전문가 영입한 삼성전자',
#   "시험 감독·스마트폰 교육을 AI가?… 삼성이 고른 '이 아이디어'",
#   '"사실 아냐"…억울한 삼성전자, 수율 두고 적극 해명 나선 이유',
#   '‘갤럭시 찐팬’들 에버랜드의 밤을 즐기다',
#   "4월 삼전 3.16% 하락…네·카 '울고' 현·기 '미소'",
#   '삼성전자, `필로토·에딘트` 스타트업 창업 지원',
#   '삼성전자 5조원대 사들인 동학개미…지난달 수익률은?',
#   "삼성전자, '에듀테크' 전문 사내벤처 2곳 창업 지원",
#   "[포커스] 위기의 한국 반도체…대만은 약진, 韓은 '빨간불'",
#   "삼성전자, hy와 함께 '우리집 전자레인지, 큐커로 교체' 캠페인",
#   "三電 연봉 9% 인상…대-중기 임금 '부익부 빈익빈' 박탈감 커진다",
#   '메모리가격 보합… 하반기 슈퍼사이클 오나',
#   '삼성전자, ‘에듀테크’ C랩 과제 2개 스타트업 창업 지원',
#   '"기업이 기업을 낳았다"…네이버 포켓몬고도 \'이것\' 덕에 탄생했다',
#   '"미슐랭 정식당에서 점심 먹어요"…복지로 인스타에서 뜬 스타트업 \'씨앤에이아이\'',
#   '“세계 반도체 공급망, 2025년께 재편 분기점 맞는다”',
#   '삼성바이오로직스 시총, 글로벌 CMO 1위 론자 넘었다',
#   "삼성전자, '갤럭시 팬파티 522랜드' 성황…2000명 참석",
#   '[공시줍줍]공모주달력 5월2일~6일',
#   '"주식 성공은 머리 아니라 엉덩이 덕"…주식 고수의 존버 정신 [자이앤트TV]',
#   '[분양현장 NOW] 축구장 32개 면적…오산 역세권 지식산업센터',
#   "한달간 6조원 넘게 순매도한 외국인…'악재 종목' 정밀 타격",
#   '국산 특화망 ‘이음5G’ 장비 출시 길 열렸다',
#   "삼성전자-hy, '우리집 전자레인지, 큐커로 교체' 캠페인 진행",
#   '"5G특화망 장비경쟁 본격화" 삼성·LG 등 전파인증 획득',
#   "삼성·LG, 5G 특화망 장비 출시…5G 자가망 사업 '탄력'",
#   '올 임금 9% 인상 삼성전자... 대기업-中企 양극화 심화',
#   '"올 여름도 덥다"…전자업계 에어컨 생산 풀가동',
#   "'증시 버팀목' 연기금, 4월에 5000억 순매수",
#   '“2025년 반도체 공급망 재편… 美 동맹 참여해야”',
#   "때 이른 여름에 유통업계, 여름 아이템 준비 '분주'",
#   '삼성전자 풀베팅한 개미, 4월 투자 수익률 -12.5%…외인은 3% 수익',
#   '“삼성전자 위기라 할 수 없지만…한국 반도체 투자 점점 느려져”',
#   '4월 4600억원 순매수 연기금, 하락장 구원투수 나서나',
#   '다시 떠나는 여행…면세업계 각종 행사 돌입',
#   '"이젠 방어주 아닌 성장주"…제일기획 목표가 줄상향',
#   "삼성전자, 5주째 외국인 순매도 '1위'…개인은 '줍줍'",
#   'LIG넥스원·현대위아…많이 번 기업이 주가도 뛰더라',
#   '4월 수출 두자릿수 성장에도…에너지값 급등에 무역적자 심화(종합)',
#   '"한국 자율차 시장 \'애플\' 될 수 있다" 그가 꽂힌 \'주차장 혁신\'',
#   '출범 1년 맞은 구본준의 LX… 공격적 M&A로 LG 의존도 낮춘다',
#   "삼성전자, '에듀테크' 관련 C랩 과제 2개 스타트업 창업 지원",
#   '尹 당선되자 기업들 돈 풀었다? 얼마나 투자했나 봤더니 [비즈360]',
#   '"바닥은 언제"…올해 20% 하락 네카오, \'눈물의 물타기\'',
#   '파이어족 꿈꾸다 파산 신청… 손절·버티기 기로에 선 영끌족 [버블이 꺼진다.. 재테크 빙하기]',
#   '문대통령, 사면 최종결심 임박…MB·김경수·이재용 등 거론',
#   '美 \'빅스텝\' 앞두고 증시 흔들…"저평가+소외 종목 주목해야"',
#   '끝 안보이는 ‘셀 코리아’…기약 없는 외인의 귀환',
#   '문대통령, 사면 결심 임박…MB·김경수·이재용 등 최종 검토(종합)',
#   'SK쉴더스 수요예측 출격, 5월 공모주시장 달아오른다',
#   "'3조 대어' SK쉴더스 출격, IPO 분위기 반전할까",
#   "'전기차 48만원, 튤립 9만원' 15초만에 완판…충성고객 잡는 NFT",
#   '[정옥재의 스마트 라이프] ‘스웨덴 감성’ 블루에어 공기청정기 한달 써보니',
#   '[주간증시전망] ‘빅스텝’이 온다…불확실성 해소, 코스피 끌어올릴까']]

# %% [markdown]
# # 각 날짜별로 주요 이슈 Top 3 요약

# %%
import nltk
import datetime as dt
import pdb

from collections import defaultdict
from sklearn.pipeline import Pipeline

from es_corpus_reader import EsCorpusReader
from korean_text_normalizer import KoreanTextNormalizer
from gensim_vectorizer import GensimTfidVectorizer
    
def classification_top_n(count_dict, n=3):
    
    for group in range(len(count_dict)):
        count_dict[group].sort()

    top_n = dict(sorted(count_dict.items(), reverse=True, key=lambda x: len(x[1]))[:n])

    i = 1

    for key in top_n.keys():
    
        print(f"*** TOP {i} Section ***")
        
        for idx, content in enumerate(top_n[key]):
            
            if idx < 5:
                print(f"{content}")
            else:
                pass
        i += 1

def classification_top_1(count_dict, n=1):
    
    for group in range(len(count_dict)):
        count_dict[group].sort()

    top_n = dict(sorted(count_dict.items(), reverse=True, key=lambda x: len(x[1]))[:n])

    i = 1

    for key in top_n.keys():
        
        for idx, content in enumerate(top_n[key]):
            
            if idx < 5:
                print(f"{content}")
            else:
                pass
        i += 1

def daily_k_means_top3(date_from, date_to):

    date_from = (dt.datetime.strptime(date_from, '%Y-%m-%d').astimezone(dt.timezone.utc) + dt.timedelta(hours=9)).isoformat()[0:10]
    date_to = (dt.datetime.strptime(date_to, '%Y-%m-%d').astimezone(dt.timezone.utc) + dt.timedelta(hours=9)).isoformat()[0:10]

    date_interval = list(pd.date_range(date_from, date_to, freq='d'))

    total_doc_count = daily_news_df(date_from, date_to)

    for time in date_interval:

        str_time = time.strftime('%Y-%m-%d')

        reader = EsCorpusReader(date_from=time, date_to=time+dt.timedelta(days=1))

        doc_num = total_doc_count.loc[time]['doc_count']
 
        corpus = list(reader.titles(n=doc_num))


        model = Pipeline([
            ('normalizer', KoreanTextNormalizer()),
            ('vectorizer', GensimTfidVectorizer())
        ])

        vectors = model.fit_transform(corpus)

        num_means = 20
        distance = nltk.cluster.cosine_distance

        kmeans = nltk.cluster.KMeansClusterer(
            num_means=num_means,
            distance=distance,
            avoid_empty_clusters=True
        )

        kmeans.cluster(vectors)

        classified = defaultdict(list)

        for doc, vec in zip(corpus, vectors):
            group = kmeans.classify(vec)
            mean = kmeans.means()[group]
            dist = distance(vec, mean)

            entry = (dist, doc)

            classified[group].append(entry)

        print(f"-------- {str_time}'s TOP 3 ISSUES --------")
        classification_top_n(classified, n=3)
        print("\n")
        
        # for group in range(len(classified)):
        #     print(f'*** Group {group} ***')

        #     classified[group].sort() #작은거에서 큰걸로 그룹안에 점수 정렬함 (양극단값이 아래로 내려가고 중앙값이 가운데로 올라옴)

        #     print("Topic Size: {}".format(len(classified[group])))

        #     for idx, x in enumerate(classified[group]):
        #         print(f'{idx}: {x}')

        #         if idx > 5:
        #             break

        #     print()

    # return classified

# %%
daily_k_means_top3('2022-05-01', '2022-05-01')
# Out:
# -------- 2022-05-01's TOP 3 ISSUES --------
# *** TOP 1 Section ***
# (0.5725384319812652, '도시가스 최대 9.4% 인상, 가구당 월평균 2450원 ↑')
# (0.5725384319812652, '도시가스 최대 9.4% 인상, 가구당 월평균 2450원 ↑')
# (0.5725384319812652, '도시가스 최대 9.4% 인상, 가구당 월평균 2450원 ↑')
# (0.5725384319812652, '도시가스 최대 9.4% 인상, 가구당 월평균 2450원 ↑')
# (0.5725384319812652, '도시가스 최대 9.4% 인상, 가구당 월평균 2450원 ↑')
# *** TOP 2 Section ***
# (0.5933230269572387, "코스닥 주간 개인 순매도 1위 '셀트리온헬스케어'")
# (0.5975677329271144, "코스피 주간 외국인 순매도 1위 '삼성전자'")
# (0.6243682925939058, "코스피 주간 개인 순매도 1위 '기아'")
# (0.62547784296566, '코스닥 주간 외국인 순매도 1위 ‘오스템임플란트’')
# (0.6260875458798656, '[표]주간?코스닥 기관·외국인·개인 순매수·순매도 상위종목(4월 25일~29일)')
# *** TOP 3 Section ***
# (0.46857542698501287, '포스코홀딩스-한전, 수소·암모니아 사업 협력')
# (0.48956362186929436, '한전, 포스코홀딩스·롯데케미칼과 수소·암모니아 사업 협력')
# (0.49491547532979174, '포스코홀딩스, 한전과 수소·암모니아 사업 협력…공동 기술개발')
# (0.49774526563459676, '한전-포스코홀딩스-롯데케미칼, 수소·암모니아 사업 협력')
# (0.504311188866472, '포스코홀딩스-한전, 수소·암모니아 사업 협력…공동 기술개발')

# %% [markdown]
# # 키워드 날짜 별로 주요 이슈 요약

# %%
from es_corpus_reader_keyword import EsCorpusReader_key

# %%
a = keyword_daily_news_trend(["인플레이션"], "2022-05-01", "2022-05-01")

# %%
from es_corpus_reader_keyword import EsCorpusReader_key

def daily_k_means_top_keyword(date_from, date_to, keyword):

    date_from = (dt.datetime.strptime(date_from, '%Y-%m-%d').astimezone(dt.timezone.utc) + dt.timedelta(hours=9)).isoformat()[0:10]
    date_to = (dt.datetime.strptime(date_to, '%Y-%m-%d').astimezone(dt.timezone.utc) + dt.timedelta(hours=9)).isoformat()[0:10]

    date_interval = list(pd.date_range(date_from, date_to, freq='d'))

    total_doc_count = keyword_daily_news_trend([keyword], date_from, date_to)

    for time in date_interval:

        str_time = time.strftime('%Y-%m-%d')

        reader = EsCorpusReader_key(date_from=time, date_to = time+dt.timedelta(days=1), keyword=keyword)

        doc_num = total_doc_count.loc[time][total_doc_count.columns[0]]
 
        corpus = list(reader.titles(n=doc_num))

        model = Pipeline([
            ('normalizer', KoreanTextNormalizer()),
            ('vectorizer', GensimTfidVectorizer())
        ])

        vectors = model.fit_transform(corpus)

        num_means = 8
        distance = nltk.cluster.cosine_distance

        kmeans = nltk.cluster.KMeansClusterer(
            num_means=num_means,
            distance=distance,
            avoid_empty_clusters=True
        )

        kmeans.cluster(vectors)

        classified = defaultdict(list)

        for doc, vec in zip(corpus, vectors):
            group = kmeans.classify(vec)
            mean = kmeans.means()[group]
            dist = distance(vec, mean)

            entry = (dist, doc)

            classified[group].append(entry)

        print(f'''-------- {str_time}'s TOP ISSUE FOR "{keyword}" --------''')
        classification_top_1(classified, n=1)
        print("\n")

# %%
daily_k_means_top_keyword("2022-05-01", "2022-05-01", "인플레이션")
# Out:
# -------- 2022-05-01's TOP ISSUE FOR "인플레이션" --------
# (0.6141550176554403, '[주간 증시 전망] 악재 선반영·실적 견조...“코스피 2630~2750P”')
# (0.6623693460352331, '[주간증시전망] 악재 선반영 기대감')
# (0.6680674664449645, '“보험사, 우크라發 금융시장 변동성에 노출…리스크 관리 필요”')
# (0.6685060151053387, '"러·우크라이나 전쟁, 국내 보험사 재무건전성에 악영향"')
# (0.6770606056354149, '증시 덮친 인플레 공포… "실적·식음료·리츠가 피난처"')

# %%
daily_k_means_top_keyword("2022-05-17", "2022-05-17", "삼성전자")
# Out:
# -------- 2022-05-17's TOP ISSUE FOR "삼성전자" --------
# (0.23987467647781446, '이재용 부회장, 고 셰이크 할리파 UAE 대통령 조문')
# (0.23987467647781446, '이재용 부회장, 고 셰이크 할리파 UAE 대통령 조문')
# (0.23987467647781446, '이재용 부회장, 고 셰이크 할리파 UAE 대통령 조문')
# (0.23987467647781446, '이재용 부회장, 고 셰이크 할리파 UAE 대통령 조문')
# (0.23987467647781446, '이재용 부회장, 고 셰이크 할리파 UAE 대통령 조문')

# %%
daily_k_means_top_keyword("2022-05-01", "2022-05-31", "전쟁")
# Out:
# -------- 2022-05-01's TOP ISSUE FOR "전쟁" --------
# (0.486914499391239, '오늘부터 휘발유 값 리터당 83원 더 내린다…유류세 30% 인하')
# (0.504222218530786, '오늘부터 유류세 30% 인하…휘발유 값 리터당 83원 내린다')
# (0.5596341776210103, '오늘부터 유류세 더 깎아준다...휘발유 최대 83원↓')
# (0.6529579440104689, '휘발유 ℓ당 83원 내린다…알뜰·직영주유소부터 즉각 적용')
# (0.6569458750563444, "하락장, 급증하는 공매도에 커지는 '개미비명'")
#
#
# -------- 2022-05-02's TOP ISSUE FOR "전쟁" --------
# (0.39084885064774566, '코로나 이전 실적 회복한 대기업…불확실성에 투자 미루고 현금 쌓아')
# (0.3962631674033553, '대기업 실적 코로나 전 회복했지만…불확실성에 현금 쌓고 투자 미뤄')
# (0.46976191266902234, '"100대 기업 실적 좋지만 투자 미루고 현금만 축적"')
# (0.48670937532056313, '100대 기업, 코로나 이전 수준 실적 회복했지만…빚 내서 현금 충전에 집중')
# (0.4956474018375724, '"100대 기업, 코로나19 이전 실적 회복했지만 빚내서 현금 축적"')
#
#
# -------- 2022-05-03's TOP ISSUE FOR "전쟁" --------
# (0.2362026424216429, '한은 “원자재가격·거리두기 해제로 당분간 4%대 물가 지속”')
# (0.27049625190072213, '한은 "물가, 당분간 4%대 오름세 지속"')
# (0.2738750939626805, '한은 "원자재가격·거리두기 해제로 당분간 물가상승률 4%대"')
# (0.2738750939626805, '한은 "원자재가격·거리두기 해제로 당분간 물가상승률 4%대"')
# (0.2952052981628761, '한은 "원자재가격 상승·거리두기 해제에 물가상승률 당분간 4%대"')
#
#
# -------- 2022-05-04's TOP ISSUE FOR "전쟁" --------
# (0.6017318087686214, '[뉴욕증시] FOMC 앞두고 상승… 금융·에너지 관련주↑')
# (0.6038483816580666, '[뉴욕마감]S&P 0.5%↑…FOMC 결정 앞두고 이틀째 상승')
# (0.6411016033717194, '뉴욕증시, FOMC 결과 발표 앞두고 이틀째 반등｜아침& 증시')
# (0.6554034719795157, '[오전시황] 금리인상 선방영한 코스피 FOMC 앞두고 상승')
# (0.6959208865118693, '미국 3월 무역적자 22% 증가…사상 첫 1천억달러 돌파')
#
#
# -------- 2022-05-05's TOP ISSUE FOR "전쟁" --------
# (0.18775725304747626, '한은 "FOMC 결과, 예상에 부합…파월 발언 다소 비둘기적"')
# (0.18775725304747626, '한은 "FOMC 결과, 예상에 부합…파월 발언 다소 비둘기적"')
# (0.18775725304747626, '한은 “FOMC 결과, 예상에 부합…파월 발언 다소 비둘기적”')
# (0.20182285331314398, '한은 "FOMC 결과, 예상에 부합… 파월 발언은 비둘기적"')
# (0.3163720801617703, '한은 "FOMC 결과, 시장 예상에 부합"')
#
#
# -------- 2022-05-06's TOP ISSUE FOR "전쟁" --------
# (0.6054067551780526, '월가 "이 속도론 물가 못잡아"…다시 고개 든 자이언트스텝')
# (0.6750228890710832, '“달라진 5월 FOMC 해석…결국 물가 둔화 시그널 필요”')
# (0.6751364582487533, '英 기준금리 또 인상…“물가 10%·내년 마이너스 성장” 경고')
# (0.6772550261305621, '코스피 종가 1%대 하락‥대한항공 주가 회복해')
# (0.6787564523267637, '[뉴욕마감]나스닥 5% 급락…"물가 잡으려면 더 공격적 긴축"')
#
#
# -------- 2022-05-07's TOP ISSUE FOR "전쟁" --------
# (0.45131864337196437, "우크라이나 밀 생산 올해 35% 감소 전망…식량위기 '고조'")
# (0.45593390537062517, '우크라이나 올해 밀 생산 35% 감소 예상…세계 식량위기 고조')
# (0.55385032916734, '"빵 값 어쩌나"…쑥대밭 된 우크라, 밀 생산 35% 줄어들것')
# (0.6496743457120164, '치솟는 물가…‘인플레이션 파이터’ ETF 담아볼까?')
# (0.6764520314742244, '유류세 인하폭 체감하려면…알뜰주유소로 가라?')
#
#
# -------- 2022-05-08's TOP ISSUE FOR "전쟁" --------
# (0.5821595938001439, '잠 못 이루는 서학개미…올해 매수 톱10 중 하나만 플러스')
# (0.6174176184285918, '달러 강세, 역환율전쟁 부르나')
# (0.6478672926510172, '인플레 나비효과…역환율전쟁 벌어지나')
# (0.6550259012416075, '국민 10명 중 4명 "기업이 살아야 \'국익·민생\'이 산다"')
# (0.667966245868433, '파업 지속 현대중공업…‘흑자전환’ 시점 멀어지나 [비즈360]')
#
#
# -------- 2022-05-09's TOP ISSUE FOR "전쟁" --------
# (0.6554361554419694, '[특징주] 중앙에너비스, G7 ‘러시아 석유 수입금지’ 발표에 강세')
# (0.7131805707050801, 'G7 "러시아 에너지 단계적 배제 약속…석유 수입금지"')
# (0.72404621082454, '[특징주] 퍼스텍, 러시아 전승절 기념 우크라이나 전쟁 전면전 선포 우려에 강세')
# (0.7332313052046329, "JP모간도 보유주식 판다…리비안 '암울'")
# (0.7367036019906305, '"원부자재 불안에 환율까지" 식품업계 이중고에 흔들린다')
#
#
# -------- 2022-05-10's TOP ISSUE FOR "전쟁" --------
# (0.5505398412020959, "물가·연준 긴축에 금융시장 '흔들'…주가 급락·환율 급등")
# (0.7201747239946583, '유동성 악화 경고한 Fed…금리 인상·물가 충격 우려도')
# (0.7292225889119044, '새 경제팀, 시작부터 가시밭…유가·물가·금리 `첩첩산중`')
# (0.730163056675786, "'S의 공포' 덮친 금융시장…코스피 2600도 깨졌다")
# (0.7314999658369602, '러-우 전쟁 여파 계속…식량 가격이 물가 흔든다')
#
#
# -------- 2022-05-11's TOP ISSUE FOR "전쟁" --------
# (0.6373158561954788, "금리인상 후 은행에 37조 몰려…떠났던 돈이 '안전' 찾아 돌아왔다")
# (0.6597212051801233, '전국 평균 경유 가격, 휘발유보다 비싸져')
# (0.6647585726212959, '휘발유보다 비싸다… 경유 가격 고공행진 이유는')
# (0.7188782839222271, "위메이드 장현국 대표 이어 박관호 의장도 '위믹스 토큰' 사들인다")
# (0.734365812281847, '[포켓이슈] 최장 18개월 이상!…내 차는 언제 나올까?')
#
#
# -------- 2022-05-12's TOP ISSUE FOR "전쟁" --------
# (0.616854955898632, '[尹정부 첫 추경] 53조 초과세수 기반한 추경, 세수펑크 우려 없나')
# (0.6547931624306508, '추경호 취임 후 첫 국제회의…“경제회복 위해 한중일 시너지 창출필요”')
# (0.6734941188564556, "'한중일 재무장관회의 첫 참석' 추경호, 금융협력 논의")
# (0.6816600231012595, '[尹정부 첫 추경] 추경호  "국채 발행없어 물가영향 최소화"')
# (0.704144416379157, "[현장영상+] 윤석열 정부 '첫 추경' 36.4조 편성...소상공인 600∼1,000만 원")
#
#
# -------- 2022-05-13's TOP ISSUE FOR "전쟁" --------
# (0.3868481142060908, '추경호 부총리-이창용 한은 총재 16일 첫 회동…경제 현안 논의')
# (0.3868481142060908, '추경호 부총리·이창용 한은 총재 16일 첫 회동…경제 현안 논의')
# (0.39800735069306015, '추경호 부총리·이창용 총재, 16일 첫 회동…경제 현안 논의')
# (0.4796281597402303, '\'첫 외부행보\' 경제 챙긴 尹대통령 "위기에 선제대응해야"(종합)')
# (0.5135787653186491, '\'첫 외부행보\' 경제 챙긴 尹대통령 "위기 선제대응해야"(종합2보)')
#
#
# -------- 2022-05-14's TOP ISSUE FOR "전쟁" --------
# (0.5685434028435239, '이번주 경유·휘발유 가격 올라…"다음주도 상승 전망"')
# (0.5685535519951725, "車 연식변경에 기본사양 추가됐지만…가격도 '껑충'")
# (0.5846714073506414, "수입 쇠고깃값 '껑충'…사료용 곡물가도 올라 육류시장 '불안'")
# (0.6052082553589351, '[뉴욕유가] 수급 불안 속에 상승…배럴당 110달러 돌파')
# (0.6438573189743995, '삼성, 역대급 매출 ‘대만 반도체’에 자극? 칩 가격 진짜 올릴까 [비즈360]')
#
#
# -------- 2022-05-15's TOP ISSUE FOR "전쟁" --------
# (0.4069678843351662, "'밀가루 대란' 오나…인도 수출금지에 국내도 긴장")
# (0.42520125130811126, "식용유 이어 '밀가루 대란' 오나…'세계 밀 생산량 2위' 인도 수출금지에 국내도 '긴장'")
# (0.6246847246553715, '세계 식량안보 위기…우크라전쟁에 인도 밀수출 금지까지')
# (0.6411220318102827, '우크라戰·이상기후, 밀값 불지른 인도까지…라면·빵값 또 오르나')
# (0.644665805005301, '뉴욕증시, 금리 발언 나올까…파월 입에 쏠린 눈')
#
#
# -------- 2022-05-16's TOP ISSUE FOR "전쟁" --------
# (0.6134282479584561, '핀트, 글로벌 시장 상황 분석 리포트 ‘핀트레터’ 발행')
# (0.6134282479584561, '핀트, 글로벌 시장 상황 분석 리포트 ‘핀트레터’ 발행')
# (0.6195314675264711, '예정처 “‘초과세수 53조’ 기재부 전망 과도…예상보다 5.5조 덜 걷힐 것”')
# (0.6365070547838854, '예정처 "기재부 초과세수 53조원 전망 과도... 47조원 수준"')
# (0.6392786592436241, '예정처 "기재부 초과세수 전망 과도…53조원 아닌 47조원 수준"')
#
#
# -------- 2022-05-17's TOP ISSUE FOR "전쟁" --------
# (0.41438450443841535, '정태영, 루나 사태에 일침 "최고 펀드도 20% 수익 약속 못해"')
# (0.4172911581763761, '정태영, 루나 폭락 사태에 "최고 펀드도 20% 수익 약속 못해"')
# (0.4314390862034052, '‘최고 펀드도 20% 수익 약속 못해’ 정태영 현대카드 부회장, 루나 사태 일침')
# (0.4636857887470047, '정태영 \'루나사태\'에 "최고 펀드도 20% 수익 약속 못해"')
# (0.4793963235810458, '정태영 현대카드 부회장 “루나사태, 최고 펀드도 20% 수익 약속못해”')
#
#
# -------- 2022-05-18's TOP ISSUE FOR "전쟁" --------
# (0.4905484017784342, "김소영 신임 금융위 부위원장 첫 일정은 '금융리스크 점검'")
# (0.5163728105423376, '김소영 신임 금융위 부위원장 "잠재 금융리스크에 위기감 가져야"')
# (0.560080261317096, '김소영 부위원장 "금융 리스크 현실화 위기감 가져야"')
# (0.5830383436134253, '김소영 부위원장 "경기 침체 우려 커져…금융사 리스크 관리해야"')
# (0.5853259918129997, '김소영 금융위 부위원장 “금융사, 손실흡수능력  갖춰야”')
#
#
# -------- 2022-05-19's TOP ISSUE FOR "전쟁" --------
# (0.5898064298975503, '건산연 "스태그플레이션 위기 극복 돌파구는 SOC 투자"')
# (0.5930007269101343, '건산연 "SOC 투자 확대로 스태그플레이션 위기 극복"')
# (0.5966390024610833, "위기에 강했던 세아그룹 '하반기도 호조 전망'")
# (0.6475804786506834, '복합 인플레 위기 도래…"닷컴버블보다 심한 재앙 닥친다"')
# (0.6969778251303205, '가격 안오른 원자재 없다…"인플레 장기화 대비해야"[공급망 위기 현실화 2]')
#
#
# -------- 2022-05-20's TOP ISSUE FOR "전쟁" --------
# (0.680667626336353, '“중국, 러시아 원유 저가에 ‘조용히’ 구입 늘려”')
# (0.689830006113702, '[뉴스새벽배송]뉴욕증시 또 하락…바이든, 韓으로 출발')
# (0.6997959637835681, '尹·바이든 "반도체 협력 강화" 엄지척…이재용 "매우 감사"(종합)')
# (0.7121090845240454, '“거래 상대방, 美 우려 대상 및 러시아 군부 관련 여부 확인해야”…전쟁 장기화에 수출 어떻게?')
# (0.7195958276511709, '워런 버핏이 \'픽\'한 이 업종…전문가도 "하락장 속 대피처"')
#
#
# -------- 2022-05-21's TOP ISSUE FOR "전쟁" --------
# (0.6092656343140401, '[한미정상회담] 외환시장 협력 첫 천명…"통화스와프 논의 지속 기대"')
# (0.6099634555647238, "바이든의 '중국 견제용' IPEF…한국의 손익계산서는")
# (0.6180169905609497, '"해외공급망 의존 큰 韓, IPEF 지분 높여야"[한미정상회담 전문가평가]')
# (0.6308220671260685, "경유價 17일째 올라 2000원 '눈앞'…휘발유價 10일째 웃돌아")
# (0.6308221370023905, '유로·달러, 20년만에 등가시대 다시 열까')
#
#
# -------- 2022-05-22's TOP ISSUE FOR "전쟁" --------
# (0.5235230492304643, "택시기사의 눈물…'LPG가격 폭등'에 법인택시 10대 중 7대 멈췄다")
# (0.5596264863578557, '무역·금융·에너지에 식량까지…정치가 경제적 질서 ‘좌지우지’')
# (0.5612276481833092, "밀 대란에도 웃지 못하는 사료주…대주주 '먹튀' 논란에 개미 한숨")
# (0.5644745133383653, '라면업계, 끊이지 않는 위기감…또 가격 올릴까?')
# (0.5802717026469945, '자동차 개소세 인하…연말까지 연장 가닥')
#
#
# -------- 2022-05-23's TOP ISSUE FOR "전쟁" --------
# (0.5757841805581818, '메리츠 "하반기 코스피 2,450∼2,850 전망…추세 반등은 4분기"')
# (0.6033492976213749, '"하반기 코스피 2,450∼2,850 전망…4분기 추세 반등"')
# (0.6773391546405172, "중소기업 부담 줄인다…정부, 하반기 '납품단가 연동제' 시범운영")
# (0.6828175605413902, '메리츠 “코스피 하반기 2450∼2850 예상…4분기 추세 반등”')
# (0.6887559193957917, '원자재값 뛰자… 납품단가 연동제, 하반기 시범운영')
#
#
# -------- 2022-05-24's TOP ISSUE FOR "전쟁" --------
# (0.5692380038378302, '인도 밀 이어 설탕 수출도 제한한다…세계 식품시장 충격 우려')
# (0.6129188728611842, '인도, 밀 이어 설탕 수출제한 움직임')
# (0.6737956068017432, '이번엔 설탕 대란?…세계 최대 생산국 인도, 수출 제한 검토')
# (0.6991805809813035, '[궁즉답]콜라를 못 만든다?..탄산 대란 무슨 일')
# (0.7170778669617756, "'김 빠진 콜라'가 웬말..탄산 대란 고비 넘기나")
#
#
# -------- 2022-05-25's TOP ISSUE FOR "전쟁" --------
# (0.6299287906851622, '러시아, 2030엑스포 유치 철회…‘부산-리야드 2파전 될 듯’')
# (0.6299287906851622, '러시아, 2030엑스포 유치 철회…‘부산-리야드 2파전 될 듯’')
# (0.6579230735882544, '인도, 밀 이어 설탕 수출도 제한…식량 보호주의 확산')
# (0.6958501841990419, '“에너지 이어 식량도 무기화”…푸틴 성토장된 다보스')
# (0.7072546637072181, "인도 설탕 수출 제한…'식량위기' 우려 커")
#
#
# -------- 2022-05-26's TOP ISSUE FOR "전쟁" --------
# (0.40446557167068753, '한은, 올해 물가 전망 3.1%→4.5%로 상향…성장률은 2.7%')
# (0.4267775855862219, '한은, 올해 물가 전망 3.1%→4.5%로 상향')
# (0.4862335070057061, "김동관 한화솔루션 사장, 다보스포럼서 '민간 경제 외교' 활동")
# (0.5045178222274689, "김동관 한화솔루션 사장, 다보스포럼서 '민간 경제 외교'")
# (0.5245039432724959, '한은, 올해 물가상승률 4.5%로 상향…성장률 2.7%로 하향(상보)')
#
#
# -------- 2022-05-27's TOP ISSUE FOR "전쟁" --------
# (0.6524335081677962, "'물가 비상' 식료품·외식·주거·교육비 총망라 '민생안정대책' 나온다")
# (0.6881670332729561, '"88년 서울올림픽 이후 최악"...유가 급등에 교역조건 뚝')
# (0.6970721119703576, '[부꾸미]인도네시아 증시 떨어지면 삼성전자 주가 오른다?')
# (0.702400278670922, '이창용 “경기침체 걱정보다 물가 잡는게 더 중요”')
# (0.7041221399948328, '한은, 치솟는 물가부터 잡는다…15년 만에 두달 연속 금리인상')
#
#
# -------- 2022-05-28's TOP ISSUE FOR "전쟁" --------
# (0.37569319174335025, '푸틴이 불붙인 식량 보호주의…기아·물가 고통 커지고 길어진다')
# (0.3757619742011583, '[뒷북경제] 한국은행이 물가가 심각하다고 본 4가지 이유')
# (0.38455826246650515, '"식판에 단백질이 없어요" 너무 오른 물가에 학교 급식도 비상 걸렸다')
#
#
# -------- 2022-05-29's TOP ISSUE FOR "전쟁" --------
# (0.5530787556487433, '스위스 찍고 독일 날아간 신학철 부회장…미래 인재 찾기 삼매경')
# (0.5747900862958848, '"씨티은행 이용 중이시군요?"…앞다퉈 쏟아진 문자')
# (0.5756069273392765, "한국은행이 '빅스텝' 고려할 4가지 요인 [조미현의 외환·금융 워치]")
# (0.5772070981833998, '[단독] 우크라 전쟁탓 비료값 폭등…농가 "팔아도 남는 게 없다"')
# (0.607349718194563, "'러-우크라 전쟁 반사익' 농산물 ETF가 챙겼다")
#
#
# -------- 2022-05-30's TOP ISSUE FOR "전쟁" --------
# (0.5846802812100496, '“반도체 관련 전문 인재 5년간 3천여 명 양성”')
# (0.5846802812100496, '“반도체 관련 전문 인재 5년간 3천여 명 양성”')
# (0.6510991153510509, '[코인뉴스] 정체된 비트코인..."통화 긴축 중단하면 반등한다"')
# (0.6750211777373101, '“하반기 유가 완만한 하락세… 무역수지도 개선”')
# (0.6973356065422474, "10년간 사들인 주식, 2년만에 죄다 팔아치운 '광란의 셀코리아'…대표주 외국인 지분율 '최저'")
#
#
# -------- 2022-05-31's TOP ISSUE FOR "전쟁" --------
# (0.3238522940612645, "4월 생산, 소비, 투자 '트리플 감소'")
# (0.4087292241027156, '생산·소비·투자 26개월 만에 ‘트리플 감소’')
# (0.4254728399144695, "4월 생산 · 소비 · 투자, 2년 2개월 만에 '트리플 감소'")
# (0.458889605092226, "4월 생산·소비·투자 '트리플 감소'…경제활동 전반 '위축'")
# (0.4959837958488572, "생산·소비·투자 '트리플 추락'…경기 침체 빨간불")

# %%
daily_k_means_top_keyword("2022-05-01", "2022-05-31", "암호화폐")
# Out:
# -------- 2022-05-01's TOP ISSUE FOR "암호화폐" --------
# (0.27984203210564995, "업비트만 쓴다고?…코인 거래소 '마이너스 수수료' 유혹")
# (0.2804540559656692, "카카오 '코인` 클레이튼, 최근 급락한 이유는?")
#
#
# -------- 2022-05-02's TOP ISSUE FOR "암호화폐" --------
# (0.23595902401950197, '빗썸, 돈워크맨과 굿네이버스에 기부금 전달')
# (0.2483671605105282, '빗썸, 웹예능 ‘돈워크맨’과 굿네이버스에 기부금 전달')
# (0.43144045833312084, '빗썸, 굿네이버스에 후원금 전달…“아이들의 꿈을 응원합니다”')
# (0.6177246326137995, '\'비트코인 구세주\' 로저 버 "머스크의 트위터 인수는 신의 한 수"')
# (0.645515176405302, '셀럽(CELEB), 더 샌드박스 내 한국복합문화공간 사업 참여')
#
#
# -------- 2022-05-03's TOP ISSUE FOR "암호화폐" --------
# (0.29815797374836084, "워런 버핏 vs 일론 머스크 '가상자산 시장 전망 승자는?'")
# (0.4029578371026826, "'엇갈리는 가상자산 시장 전망…최후의 승자는?'")
# (0.41581105245161654, "워런 버핏 vs 일론 머스크 '가상자산 시장 전망 놓고 이견'")
# (0.42541801629785736, "'엇갈리는 가상자산 시장 전망'")
# (0.4637817818117351, "'가상자산 시장 놓고 평가 엇갈리는 워런 버핏과 일론 머스크'")
#
#
# -------- 2022-05-04's TOP ISSUE FOR "암호화폐" --------
# (0.46447733177489003, 'FOMC 앞두고 차익실현 나선 듯…암호화폐 일제 하락(종합)')
# (0.4819229397571215, "지난해 500대 기업 순위 변동…'배터리·암호화폐' 뜨고 '항공·유통' 졌다")
# (0.4942145418189797, "[가상화폐 시세] '2만7000달러 하락 대비하라' 투자자문사 대표의 경고")
# (0.5116555953370198, '업비트, 케이뱅크서 이자받고도 고객에게는 지급 안해')
#
#
# -------- 2022-05-05's TOP ISSUE FOR "암호화폐" --------
# (0.28478387091518376, "비트코인, 연준 '자이언트스텝' 해소에 5%↑… 4만달러 '코앞'")
# (0.3363476591564325, '“땡큐 파월” 비트코인 5.68% 급등해 4만달러 근접(상보)')
# (0.37460381160005707, '연준 금리 인상 선 긋기에 비트코인 한때 4만달러 육박')
#
#
# -------- 2022-05-06's TOP ISSUE FOR "암호화폐" --------
# (0.2960761685684872, '머스크, 트위터 인수 위해 9조원 투자 유치…임시CEO 맡을듯(종합)')
# (0.35660462231983325, '머스크, 트위터 인수에 사우디 왕자도 끌어들였다…9조원 투자 유치(종합)')
# (0.3826204421813364, '일론 머스크, 트위터 인수 자금 9조원 투자 유치 성공')
# (0.3864152962622023, '머스크, 트위터 인수 위해 9조원 유치…테슬라 8.33%↓')
# (0.42642427168472086, '머스크, 트위터 인수위해 9조원 투자 유치…사우디 왕자 등')
#
#
# -------- 2022-05-07's TOP ISSUE FOR "암호화폐" --------
# (0.48755828104131504, '비트코인 또 하락, 3만5000달러 대까지 밀려(상보)')
# (0.5263408793815059, '하루에 그친 비트코인 랠리…주요국 코인 규제는 ‘점입가경’ [위클리 코인리뷰]')
# (0.5462566095300719, "건축→은행→블록체인 '커리어 전환' 3번… '갑자기'는 없었다")
# (0.5550646253107464, '우표, 운동화 대신 NFT 수집하는 세상 온다')
# (0.5798819933879404, '“밸류에이션 대비 저평가돼 있는 종목, 매수 기회”')
#
#
# -------- 2022-05-08's TOP ISSUE FOR "암호화폐" --------
# (0.27715115644961175, "구찌, 비트코인으로 산다…명품업체 '코인 결제' 뛰어든 이유")
# (0.277352568380529, '[오늘의 코인]급락하는 시장, 바닥인줄 알았는데 지하가 있었네')
#
#
# -------- 2022-05-09's TOP ISSUE FOR "암호화폐" --------
# (0.4535176673299949, '비트코인 美 금리인상에 하락, 3만4천달러선 붕괴')
# (0.471147845757393, '비트코인, 끝없는 하락 3만4000달러 붕괴')
# (0.49025513413873123, '비트코인, 하락 지속 3만4000달러 붕괴')
# (0.5309885215779644, '하락세 이어지는 비트코인, 3만4천달러 붕괴')
# (0.5361878089945658, '비트코인, 3만4천달러선 붕괴')
#
#
# -------- 2022-05-10's TOP ISSUE FOR "암호화폐" --------
# (0.45652678968683724, "美 증시 급락에 비트코인 3만 달러 위태...엘살바도르는 '줍줍'")
# (0.5880952102804051, '엘살바도르, 비트코인 폭락하자 500개 추가 매수…‘평균 3만744달러에 저가 매수’')
# (0.5884375643194232, '코빗, 어린이날 맞아 넥슨어린이재활병원에 기부금 전달')
# (0.5904687172755253, '엘살바도르, 비트코인 가격 폭락하자 500개 추가 매수')
# (0.596612215576537, '코빗, 어린이날 100주년 맞아 넥슨어린이재활병원에 기부금 전달')
#
#
# -------- 2022-05-11's TOP ISSUE FOR "암호화폐" --------
# (0.523693257902268, '스테이블 코인 테라의 몰락?…코인시장에 암운')
# (0.5824783249336638, "코인 공부 중인 '카뱅'…암호화폐 뛰어드나")
# (0.5878984142659203, '[코인시황] 위태로운 코인시장…4000만원 턱걸이 중인 비트코인')
# (0.6118113111142917, '연준 이어 美 재무부도 스테이블 코인 경고...재닛 옐런 "연내에 규제 시작해야"')
# (0.6229256871944994, 'CNBC "韓 테라가 발행한 UST가 비트코인 3만달러 붕괴시켜"')
#
#
# -------- 2022-05-12's TOP ISSUE FOR "암호화폐" --------
# (0.38622921270491595, '미 증시 폭락, 루나 사태에 비트코인 휘청')
# (0.38622921270491595, '미 증시 폭락, 루나 사태에 비트코인 휘청')
# (0.38622921270491595, '미 증시 폭락, 루나 사태에 비트코인 휘청')
# (0.38622921270491595, '미 증시 폭락, 루나 사태에 비트코인 휘청')
# (0.572175109320826, '비트코인도 끌어내린 테라·루나… ‘리먼 사태’ 재현하나')
#
#
# -------- 2022-05-13's TOP ISSUE FOR "암호화폐" --------
# (0.5641608304201378, '“119달러에서 0.005달러 됐다” 끝없이 추락하는 루나, 바이낸스는 상장 폐지 결정')
# (0.6356156462164759, '비트코인 폭락세는 멈춰…0.67% 하락한 2만8273달러(상보)')
# (0.6403578324717936, '뉴욕증시, 위험회피 심리에 하락…다우 0.33% 떨어져')
# (0.656696718138118, '비트코인 10% 폭등, 3만 재돌파…테라 충격 극복하는 듯(상보)')
# (0.6791735642413506, '흔들리는 테라 블록체인 생태계에…컴투스그룹, 테라 떠난다')
#
#
# -------- 2022-05-14's TOP ISSUE FOR "암호화폐" --------
# (0.32783703359042393, '루나·테라 개발한 권도형 “내 발명품 모두에 고통 줬다”')
# (0.34452613247153874, '‘테라’ 권도형 “루나 안 팔았다…내 발명품, 모두에게 고통줘”')
# (0.351540750809767, '휴지조각된 K코인…권도형 "내 발명품이 고통 줘, 루나 안 팔았다"')
# (0.3515603114038611, '\'루나 폭락\' 권도형 "내 발명품 모두에 고통 줘 비통"')
# (0.3524038777988432, 'K코인 지옥행…테라 권도형 "내 발명품, 모두에 고통 줬다"')
#
#
# -------- 2022-05-15's TOP ISSUE FOR "암호화폐" --------
# (0.26519770919074614, '비트코인 3,900만원대 보합권…시장, 테라·루나 사태 여파 주목')
# (0.31104118505376244, '비트코인 3900만원대 보합권… 테라·루나 사태 여파 주목')
# (0.3165528954936334, '비트코인 3,900만원대 보합권…시장, 테라·루나 사태 여파 주목(종합)')
# (0.3575245263156286, "비트코인 3,900만원대 보합권…'테라·루나 사태' 여파 촉각")
# (0.5691178768102685, '비트코인 3900만원대 보합…‘죽음의 소용돌이’ 여파 주목')
#
#
# -------- 2022-05-16's TOP ISSUE FOR "암호화폐" --------
# (0.19637604122769647, "'테라 사태 후 비트코인 어떻게 될까'")
# (0.19637604122769647, "'테라 사태 후 비트코인 어떻게 될까'")
# (0.32608374015327857, "'비트코인 어떻게 될까'")
# (0.32608374015327857, "'비트코인 어떻게 될까'")
# (0.32608374015327857, "'비트코인 어떻게 될까'")
#
#
# -------- 2022-05-17's TOP ISSUE FOR "암호화폐" --------
# (0.41984636210197623, '루나 폭락 사태, 비트코인의 미래는?')
# (0.5260645971830142, "'암호화폐의 미래는?'")
# (0.5260645971830142, "'암호화폐의 미래는?'")
# (0.5684468795142854, "상장폐지 앞둔 '루나'")
# (0.5684468795142854, "상장폐지 앞둔 '루나'")
#
#
# -------- 2022-05-18's TOP ISSUE FOR "암호화폐" --------
# (0.4795425086631874, "루나-테라 사태 속 '스테이블코인 1위' 테더 9조원 인출")
# (0.5296261289126682, '[코인시황] 루나-테라 사태에 美 증시 상승에도 비트코인 보합세')
# (0.5912080677246232, "'테라 사태' 속 1위 스테이블코인 테더에서도 12조7000억원 인출")
# (0.6204340480340527, '비트코인, 나스닥 상승에도 3만달러 보합… 알트코인 부진')
# (0.6404280578850207, '[오늘의 코인] 루나·테라 코인 여파로 보합세 보이는 시장')
#
#
# -------- 2022-05-19's TOP ISSUE FOR "암호화폐" --------
# (0.5415561193641376, '하락하는 비트코인')
# (0.5415561193641376, '하락하는 비트코인')
# (0.5483382025650179, "루나 새 코인 발행 반대에도…'테라2.0' 강행하나")
# (0.6554295555424599, "'50조 증발' 피눈물에도…'테라2.0' 강행하는 고래들")
# (0.6558801793854883, '"또 만든다고?"...권도형 \'테라 부활\' 프로젝트 강행할까')
#
#
# -------- 2022-05-20's TOP ISSUE FOR "암호화폐" --------
# (0.550331459231928, "'루나·테라' 사태에 놀란 G7..암호화폐 규제 속도 빨라지나")
# (0.6016036465094913, "루나·테라 폭락 사태, '여의도 저승사자' 합수단에 배당")
# (0.617188543293312, "'루나 사태' 점검 나선 당정…5대 코인거래소 대표 소집")
# (0.620660319390455, "당정, '루나 사태' 긴급 간담회…5대 코인거래소 대표 소집령")
# (0.6219995109285983, '루나 당정 간담회 암호화폐 거래소 투자자보호 점검…김소영 금융위 부위원장도 참석')
#
#
# -------- 2022-05-21's TOP ISSUE FOR "암호화폐" --------
# (0.40079435598884494, '"가상화폐는 아무 가치도 없어...투기 막아야" ECB 총재 \'경고\'')
# (0.44334225919153347, '이병욱 "가상화폐 투자? 차라리 복권 사라"[한판승부]')
# (0.473387590096499, '성적표 나오는 엔비디아…주가상승 신호탄 될까')
# (0.48865594400874446, '[뉴스쉽] 끝나지 않는 파티는 없다…거품 붕괴와 저성장의 도래')
#
#
# -------- 2022-05-22's TOP ISSUE FOR "암호화폐" --------
# (0.25126266451914814, '테라 권도형 "한국에 미납 세금 없다…살해 위협 두렵지 않나? NO"')
# (0.3649287631620366, '테라 권도형, 탈세·해외도피 의혹에 \'NO\'…"살해 위협 두렵지 않다"(종합)')
# (0.3716678635216968, '[뉴스IT쥬]끝나지 않는 \'테라·루나\' 충격…권도형 "살해 위협 두렵지 않다"')
# (0.5653771173792426, '권도형 테라폼랩스 CEO “국세청 세무조사 악의적…살해위협 두렵지 않다”')
# (0.6120193876603057, '‘루나’ 권도형 “한국 미납 세금 없다…싱가포르 체류 중”')
#
#
# -------- 2022-05-23's TOP ISSUE FOR "암호화폐" --------
# (0.5187460288525171, '있어도 못막은 ‘루나·테라’ 사태…가상자산법 살펴보니')
# (0.5327413351124402, '"루나-테라, 불법유사수신 적용 힘들 듯"')
# (0.5649269819619145, '[코인시황] 루나 사태로 움츠린 코인 시장…비트코인 3900만원대')
# (0.5695808647566294, '“루나 꼴 나나”… 테더 달러 보유량 3% 불과, 폰지사기 의혹 증폭')
# (0.5804948130255279, "당정, '테라 사태' 머리 맞댄다…업계 '자율 지침' 나오나")
#
#
# -------- 2022-05-24's TOP ISSUE FOR "암호화폐" --------
# (0.2214917356562197, 'IMF 총재, 루나·테라 사태 “피라미드 사기” 비판')
# (0.2214917356562197, 'IMF 총재, 루나·테라 사태 “피라미드 사기” 비판')
# (0.2214917356562197, 'IMF 총재, 루나·테라 사태 “피라미드 사기” 비판')
# (0.2832909075044815, 'IMF 총재 "루나·테라 사태는 피라미드 사기" 비판(종합)')
# (0.4476644015335478, '각국 중앙은행 총재들, 가상화폐 비판')
#
#
# -------- 2022-05-25's TOP ISSUE FOR "암호화폐" --------
# (0.3788779092119773, '코빗, 내달 루나 상장폐지… "수수료 수익은 투자자 보호 활용"')
# (0.39086865193788156, '코빗도 루나 상폐…“수수료 수익 전액, 투자자 보호에”')
# (0.4490808029569584, '코빗, 내달 3일 루나 거래 지원 종료…"수수료 투자자 보호에 활용"')
# (0.45219311580222254, '코빗 내달 3일 2시 루나 상장폐지…"수수료 수익 전액 투자자 보호에 쓸 것"')
# (0.46588475040023924, '코빗, 루나 거래 종료 결정… “수수료 수익으로 투자자 보호 나선다”')
#
#
# -------- 2022-05-26's TOP ISSUE FOR "암호화폐" --------
# (0.3897453641844282, '테라 "테라 2.0 곧 온다…새 루나·테라 블록체인 부활할 것"')
# (0.44341246564953274, '"테라 2.0 온다"… 새 루나·블록체인, 이르면 27일 가동')
# (0.45094033096746833, "대폭락했던 테라, '테라 2.0'으로 부활…이르면 27일 가동")
# (0.5042060459742745, "대폭락 테라 '테라 2.0'으로 이르면 27일 부활....권도형, 투표강행해 '찬성 65%' 얻어")
# (0.5084692836278164, "권도형의 '테라 2.0' 부활한다…기존 루나·테라 보유한 사람은?")
#
#
# -------- 2022-05-27's TOP ISSUE FOR "암호화폐" --------
# (0.3958819877417663, '테라 충격 지속, 솔라나 10%-아벨란시 15% 알트코인 일제↓(상보)')
# (0.43248772214938325, '이더 7%-솔라나 10%-아벨란시 15% 일제히 폭락 이유는?(종합)')
# (0.4868342878718558, '나스닥 급등에도 비트코인 0.5% 하락, 2만9000달러대(상보)')
# (0.5487820088010716, '나스닥 급등에도 암호화폐 일제↓ 디커플링 발생(종합)')
# (0.6067716870372034, '美증시, 내부자 매수 늘었다…"3개월간 15% 랠리 시작"[오미주]')
#
#
# -------- 2022-05-28's TOP ISSUE FOR "암호화폐" --------
# (0.38038157999320643, '루나 상폐 날짜 제각각…왜')
# (0.3846731396547092, '“응, 네 엄마 돈으로” 독선적 루나 설계자의 예견된 종말')
# (0.38795599691336957, '“‘루나 사태’는 ‘옥석 가리기’…가상자산 규제, 산업 발전과 균형 맞춰야”')
#
#
# -------- 2022-05-29's TOP ISSUE FOR "암호화폐" --------
# (0.26285159959866944, "가상자산 시장 덮친 '테라 사태'… 비트코인 ETF·관련주도 '우수수'")
# (0.2634188188806096, '[오늘의 코인] 뉴욕증시와 디커플링 의견…시장 보합권에서 등락')
#
#
# -------- 2022-05-30's TOP ISSUE FOR "암호화폐" --------
# (0.5446818690419643, '"우린 달라" 루나·테라 폭락에도 끄떡없는 위메이드, 미르M으로 도약')
# (0.5634214272653997, '[특징주] 위메이드, 루나·테라 폭락에도 6%↑… 미르M 기대감 UP')
# (0.5696316467742637, '[단독] 단돈 \'2달러\'로 회사 세운 권도형…테라 관계자 "루나 2.0 새 기술 없다"')
# (0.6425673360326561, "[단독] 테라 법인 설립 문서 입수…자본금 단돈 '2달러'")
# (0.651593725515732, '테라 롤러코스터에서 내려 다음 열차를 기다리다')
#
#
# -------- 2022-05-31's TOP ISSUE FOR "암호화폐" --------
# (0.5739886495869142, '[비트코인 지금]中 코로나 봉쇄 완화에 3만1000달러대 복귀')
# (0.5779726204969156, "中 코로나 봉쇄 완화 소식에 '들썩'… 비트코인·이더리움 등 급등")
# (0.6369003326098335, '테라·루나 비판한 싱가포르 부총리 “코인 멀리 하라”')
# (0.6386723433035242, '8주연속 하락한 비트코인, 본격 반등?…中 봉쇄완화 기대에 상승')
# (0.6592790820119174, '[코인뉴스] 회복세 보이는 비트코인... 4000만원 넘어설까')

# %% [markdown]
# # My Portfolio

# %%
# 코스닥, 코스피 종목코드 yf에서 추출
import pandas as pd
import FinanceDataReader as fdr
import yfinance as yf

from dateutil.relativedelta import relativedelta
import matplotlib as plt

# %%
kospi_all_stock_df = fdr.StockListing('KRX')
stockcode = kospi_all_stock_df[['Symbol', 'Market', 'Name']]

# %%
#함수들 모음

# 날짜: 자동으로 설정
# 티커: 함수이용

# 해당하는 종목코드 추출

def code_list_create (port_list):
    code_list = []
    for i in port_list:
        code_list.append(code(i))

    return code_list
    

def code(name):

    a = stockcode[stockcode['Name'] == name]
    a_code = a['Symbol'].item()
    a_market = a['Market'].item()
    
    if a_market == 'KOSPI':
        a_market = '.KS'
    
    elif a_market == 'KOSDAQ':
        a_market = '.KQ'
    
    return a_code + a_market

def port_weight_creator (port, date_from, date_to):
    
    port_list = port['종목명'].to_list()

    port = port.set_index('종목명')

    port_dict = {}

    for k in port_list:
        port_dict[code(k)] = k

    code_list = code_list_create(port_list)

    date_from = pd.to_datetime(date_from) - dt.timedelta(days=5)
    date_to = pd.to_datetime(date_to) + dt.timedelta(days=1)
    str_date_from = date_from.strftime("%Y-%m-%d")
    str_date_to = date_to

    df = yf.download(code_list, start=str_date_from, end=date_to, progress=False)['Adj Close']
    df2 = df.pct_change()

    for i in list(port_dict.keys()):
        df.rename(columns={i: port_dict[i]}, inplace=True)

    for i in list(port_dict.keys()):
        df2.rename(columns={i: port_dict[i]}, inplace=True)


    port['weight'] = df.iloc[-1,:].T
    port['weight'] = (port['수량'] * port['weight']) / (port['수량'] * port['weight']).sum()
    port['price'] = df.iloc[-1,:].T
    port['yet_ret'] = df2.iloc[-1,:].T

    return port

# 어제 수익률 보기
def yesterday_rtn(list, date_from, date_to):

    date_from = pd.to_datetime(date_from) - dt.timedelta(days=5)

    df = yf.download(list, start=date_from, end=date_to, progress=False)

    df['daily_rtn'] = df['Adj Close'].pct_change()
    last_rtn = df['daily_rtn'][-1].item()
    
    return last_rtn

# 한달동안 일별 수익률 추이 보기
def monthly_rtn_graph(name):
    
    b = code(name)
    
    today = dt.datetime.today()
    monthago = dt.datetime.today() - relativedelta(months=1)

    df = yf.download(b, start=str(monthago), end=str(today), progress=False)
    df['daily_rtn'] = df['Adj Close'].pct_change()

    return df['daily_rtn'].plot()

# %%
port = pd.read_excel("Portfolio.xlsx")
df = port_weight_creator(port, "2022-05-17", "2022-05-17")
df
# Out:
#           수량    weight     price   yet_ret
# 종목명
# 셀트리온     130  0.064972  142500.0  0.010638
# 삼성전자     222  0.052634   67600.0  0.019608
# 신세계       89  0.080846  259000.0  0.007782
# 카카오      888  0.259121   83200.0  0.010936
# 효성      1000  0.291102   83000.0  0.008505
# SK하이닉스   200  0.078913  112500.0  0.018100
# KB금융     288  0.058585   58000.0 -0.011925
# 대한항공    1123  0.113827   28900.0  0.000000

# %% [markdown]
# # URL

# %%
def classification_top_1_return_title (count_dict, n):
    
    for group in range(len(count_dict)):
        count_dict[group].sort()

    top_n = dict(sorted(count_dict.items(), reverse=True, key=lambda x: len(x[1]))[:n])

    i = 1

    tmp_list = []

    for key in top_n.keys():
        
        for idx, content in enumerate(top_n[key]):
            
            if idx < 1:
                tmp_list.append(content)
            else:
                pass
        i += 1

    return tmp_list

def download_total_url_from_title (date_from, date_to, title):

    date_from = dt.datetime.strptime(date_from, '%Y-%m-%d').isoformat()[0:10]
    date_to = dt.datetime.strptime(date_to, '%Y-%m-%d').isoformat()[0:10]

    date_interval = list(pd.date_range(date_from, date_to, freq='d'))

    # print("Downloading data from OpenSearch server")

    total_title_list = []

    for i in range(len(date_interval)):

        str_date = date_interval[i].strftime('%Y-%m-%d')

        # print(f"{str_date} Start!")

        daily_title_list = []

        start_date = date_interval[i]
        end_date = date_interval[i] + relativedelta(days=1)

        for page in range(1000):

#            print('.', end='', flush=True)

            hits = fetch_news_docs_title(start_date, end_date, page, title)

            if len(hits) == 0:
                break

            for doc in hits:
            
                daily_title_list.append(get_bodies(doc))

        total_title_list.append(daily_title_list)

        # print("***" + str_date + "End!" + "***")

    # print("Daily Data end!")

    return total_title_list



from es_corpus_reader_title import EsCorpusReader_title

def daily_k_means_top_keyword_with_url(date_from, date_to, keyword):

    date_from = (dt.datetime.strptime(date_from, '%Y-%m-%d').astimezone(dt.timezone.utc) + dt.timedelta(hours=9)).isoformat()[0:10]
    date_to = (dt.datetime.strptime(date_to, '%Y-%m-%d').astimezone(dt.timezone.utc) + dt.timedelta(hours=9)).isoformat()[0:10]

    date_interval = list(pd.date_range(date_from, date_to, freq='d'))

    total_doc_count = keyword_daily_news_trend([keyword], date_from, date_to)

    for time in date_interval:

        str_time = time.strftime('%Y-%m-%d')

        reader = EsCorpusReader_key(date_from=time, date_to = time+dt.timedelta(days=1), keyword=keyword)

        doc_num = total_doc_count.loc[time][total_doc_count.columns[0]]
 
        corpus = list(reader.titles(n=doc_num))

        model = Pipeline([
            ('normalizer', KoreanTextNormalizer()),
            ('vectorizer', GensimTfidVectorizer())
        ])

        vectors = model.fit_transform(corpus)

        num_means = 8
        distance = nltk.cluster.cosine_distance

        kmeans = nltk.cluster.KMeansClusterer(
            num_means=num_means,
            distance=distance,
            avoid_empty_clusters=True
        )

        kmeans.cluster(vectors)

        classified = defaultdict(list)

        for doc, vec in zip(corpus, vectors):
            group = kmeans.classify(vec)
            mean = kmeans.means()[group]
            dist = distance(vec, mean)

            entry = (dist, doc)

            classified[group].append(entry)

        print(f'''-------- {str_time}'s 3 TOP ISSUES FOR "{keyword}" --------''')
        returned_title = classification_top_1_return_title(classified, n=3)

        count = 1
        for i in returned_title:
            reader = EsCorpusReader_title(date_from=time, date_to = time+dt.timedelta(days=1), title=i[1])
            corpus = list(reader.urls(n=1))[0]

            print(f"{count} ISSUE : {i[1]}")
            print(f"URL = {corpus}")
            count += 1

        print("\n")

# %%
daily_k_means_top_keyword_with_url("2022-05-17", "2022-05-17", "삼성전자")
# Out:
# -------- 2022-05-17's 3 TOP ISSUES FOR "삼성전자" --------
# 1 ISSUE : 이재용 부회장, 고 셰이크 할리파 UAE 대통령 조문
# URL = https://n.news.naver.com/mnews/article/001/0013184589?sid=101
# 2 ISSUE : 바이든, 4대그룹 총수·6대 경제단체장 만난다…한미정상 만찬에 동석
# URL = https://n.news.naver.com/mnews/article/448/0000360301?sid=101
# 3 ISSUE : 기관 매수세에 코스피 1% 가까이 상승 마감…2620선 회복
# URL = https://n.news.naver.com/mnews/article/277/0005090249?sid=101

# %%
for i in port_list:
    daily_k_means_top_keyword_with_url("2022-05-17", "2022-05-17", i)
# Out:
# -------- 2022-05-17's 3 TOP ISSUES FOR "셀트리온" --------
# 1 ISSUE : 셀트리온, '악템라 바이오시밀러' 글로벌 임상 3상 개시
# URL = https://n.news.naver.com/mnews/article/417/0000813657?sid=101
# 2 ISSUE : 셀트리온, '악템라' 바이오시밀러 'CT-P47' 유럽 3상 신청
# URL = https://n.news.naver.com/mnews/article/011/0004054494?sid=101
# 3 ISSUE : 바이넥스, 강소 CMO로 자리매김…"삼바만 있는 게 아냐"
# URL = https://n.news.naver.com/mnews/article/008/0004747136?sid=101
#
#
# -------- 2022-05-17's 3 TOP ISSUES FOR "삼성전자" --------
# 1 ISSUE : 바이든, 4대 그룹 총수 이어 경제6단체장도 만난다
# URL = https://n.news.naver.com/mnews/article/003/0011190081?sid=101
# 2 ISSUE : 코스피, 기관 매수에 소폭 상승 출발…2610선 회복
# URL = https://n.news.naver.com/mnews/article/031/0000672879?sid=101
# 3 ISSUE : 이재용 부회장, 고 셰이크 할리파 UAE 대통령 조문
# URL = https://n.news.naver.com/mnews/article/001/0013184589?sid=101
#
#
# -------- 2022-05-17's 3 TOP ISSUES FOR "신세계" --------
# 1 ISSUE : '홈리빙 1위' 모던하우스 5년만에 매물로
# URL = https://n.news.naver.com/mnews/article/001/0013185273?sid=101
# 2 ISSUE : 면세업계, 매출 늘었지만 손실도 증가…언제쯤 살아날까?
# URL = https://n.news.naver.com/mnews/article/003/0011190165?sid=101
# 3 ISSUE : 믿을 건 실적뿐… 5분기 연속 '깜짝 실적' 올린 기업은
# URL = https://n.news.naver.com/mnews/article/014/0004837749?sid=101
#
#
# -------- 2022-05-17's 3 TOP ISSUES FOR "카카오" --------
# 1 ISSUE : 기관 '사자'에 코스피·코스닥 동반 상승…삼성전자 1%대 ↑
# URL = https://n.news.naver.com/mnews/article/277/0005090037?sid=101
# 2 ISSUE : "주문하면 환경 개선"…카카오메이커스 '에코씨드 캠페인' 진행
# URL = https://n.news.naver.com/mnews/article/421/0006096597?sid=101
# 3 ISSUE : 코스피, 반도체주 강세에 상승…2620선 마감
# URL = https://n.news.naver.com/mnews/article/031/0000673062?sid=101
#
#
# -------- 2022-05-17's 3 TOP ISSUES FOR "효성" --------
# 1 ISSUE : 중기부, 민관협력 오픈이노베이션 프로그램 참여 스타트업 모집
# URL = https://n.news.naver.com/mnews/article/215/0001032005?sid=101
# 2 ISSUE : 효성, 마포구 취약계층 청소년 장학금 2천만원 전달
# URL = https://n.news.naver.com/mnews/article/119/0002604673?sid=101
# 3 ISSUE : 효성, 마포구 청소년 위한 장학금 2000만원 전달
# URL = https://n.news.naver.com/mnews/article/014/0004837679?sid=101
#
#
# -------- 2022-05-17's 3 TOP ISSUES FOR "SK하이닉스" --------
# 1 ISSUE : 대기업 올해 1분기 매출 700조원 첫 돌파
# URL = https://n.news.naver.com/mnews/article/422/0000542334?sid=101
# 2 ISSUE : 코스피, 기관 나홀로 '사자'에 0.9%↑… 2620선 회복
# URL = https://n.news.naver.com/mnews/article/417/0000813922?sid=101
# 3 ISSUE : SK에코플랜트 재무안정성 개선…1분기 부채비율 큰 폭 감소
# URL = https://n.news.naver.com/mnews/article/009/0004965022?sid=101
#
#
# -------- 2022-05-17's 3 TOP ISSUES FOR "KB금융" --------
# 1 ISSUE : 코스피, 반도체주 강세에 상승…2620선 마감
# URL = https://n.news.naver.com/mnews/article/031/0000673062?sid=101
# 2 ISSUE : 동학개미운동 부질없나…올해 순매수 상위 종목 일제히 마이너스
# URL = https://n.news.naver.com/mnews/article/009/0004964882?sid=101
# 3 ISSUE : 이창권號 KB국민카드, 해외사업 '전략적 확대' 박차
# URL = https://n.news.naver.com/mnews/article/031/0000673085?sid=101
#
#
# -------- 2022-05-17's 3 TOP ISSUES FOR "대한항공" --------
# 1 ISSUE : "여행하며 마일리지 배로"…대한항공, '여행의 정석' 프로모션
# URL = https://n.news.naver.com/mnews/article/008/0004746874?sid=101
# 2 ISSUE : 국제유가 상승...유류할증료 역대 최고치 경신
# URL = https://n.news.naver.com/mnews/article/003/0011189882?sid=101
# 3 ISSUE : 항공업계 1분기 실적 희비…대형사는 역대 최대 실적, LCC는 적자 지속
# URL = https://n.news.naver.com/mnews/article/076/0003868832?sid=101

# %% [markdown]
# # Sentiment

# %%
from konlpy.tag import Hannanum
from config import * # config안의 정보 가져오기
from transformers import pipeline
import re
import tensorflow as tf


# model_review = keras.models.load_model('models/best_model_hannanum_review copy.h5')
# model_up_down = keras.models.load_model('models/best_model(Okt) copy.h5')

#tokenizer = Tokenizer()
han = Hannanum()
classifier = pipeline('sentiment-analysis', model='snunlp/KR-FinBert-SC')

# %%
def sentiment_hugging_face_docs(date_from, date_to, port_list):

    date_from = (dt.datetime.strptime(date_from, '%Y-%m-%d').astimezone(dt.timezone.utc) + dt.timedelta(hours=9)).isoformat()[0:10]
    date_to = (dt.datetime.strptime(date_to, '%Y-%m-%d').astimezone(dt.timezone.utc) + dt.timedelta(hours=9)).isoformat()[0:10]

    doc_list = []
    for i in port_list:
        doc_list.append(download_total_title_keyword(date_from, date_to, i)[0])

    # return doc_list
    sentiment_score = hugging_list(doc_list)

    return sentiment_score
    

def hugging_list (doc_list):
    '''list가 있어요, 그 안에 리스트가 또 있어요 하하 [ [삼성전자 글들...] ], [셀트리온 글들...], [ㅇㄹㅇㄹㅇㄹ]  ] '''
    sentiment_score = list()

    for i in range(len(doc_list)):

        result = classifier(doc_list[i])

        neutral_score = 1
        positive_score = 1
        negative_score = 1


        for k in range(len(result)):
            #print(f"제목 : {i[k]}")
            #print(f"이 뉴스는 {round(result[k]['score'] * 100, 2)}% 확률로 {result[k]['label']} 입니다.\n")

            if result[k]['label'] == 'neutral':
                neutral_score *= 0
            elif result[k]['label'] == 'positive':
                positive_score += 1 * result[k]['score']
            else:
                negative_score += (-1) * result[k]['score']

        if len(result) == 0:
            total_score = np.nan
            sentiment_score.append(total_score) 
        else:
            total_score = (neutral_score + positive_score + negative_score) / len(result) 
            sentiment_score.append(total_score) 

    # print(f"neutral : {neutral_score/len(result)}")
    # print(f"positive : {positive_score/len(result)}")
    # print(f"negative : {negative_score/len(result)}")

        # print(f"Sentiment Score of {port_list[i]} : {total_score}")

    return sentiment_score

# %%
port_list = port['종목명'].to_list()
sentiment_score_port = sentiment_hugging_face_docs("2022-05-17", "2022-05-17", port_list)
sentiment_score_port
# Out:
# [0.8753104615211487,
#  0.14690165694855967,
#  0.2373142049593084,
#  0.20780827283859252,
#  0.5624021962285042,
#  0.3539315789518222,
#  0.3282157911194695,
#  0.0727805742403356]

# %%
df
# Out:
#           수량    weight     price   yet_ret
# 종목명
# 셀트리온     130  0.064972  142500.0  0.010638
# 삼성전자     222  0.052634   67600.0  0.019608
# 신세계       89  0.080846  259000.0  0.007782
# 카카오      888  0.259121   83200.0  0.010936
# 효성      1000  0.291102   83000.0  0.008505
# SK하이닉스   200  0.078913  112500.0  0.018100
# KB금융     288  0.058585   58000.0 -0.011925
# 대한항공    1123  0.113827   28900.0  0.000000

# %%
df['snt_news_title_score'] = sentiment_score_port

# %%
df
# Out:
#           수량    weight     price   yet_ret  snt_news_title_score
# 종목명
# 셀트리온     130  0.064972  142500.0  0.010638              0.875310
# 삼성전자     222  0.052634   67600.0  0.019608              0.146902
# 신세계       89  0.080846  259000.0  0.007782              0.237314
# 카카오      888  0.259121   83200.0  0.010936              0.207808
# 효성      1000  0.291102   83000.0  0.008505              0.562402
# SK하이닉스   200  0.078913  112500.0  0.018100              0.353932
# KB금융     288  0.058585   58000.0 -0.011925              0.328216
# 대한항공    1123  0.113827   28900.0  0.000000              0.072781

# %%
df['snt_news_title_score'].T @ df['weight']
# Out:
# 0.3567951339189711

# %% [markdown]
# # ********** 여기서부터 추가 ************

# %%
import crawling
import scoring
import FinanceDataReader as fdr

# %%
# stocks = fdr.StockListing('KRX')
# stockcode = stocks[['Symbol', 'Market', 'Name']] (굳이 재정이 노필요 맨 첨에 그냥 할것)

# %%
data = crawling.consensus_crawling_DB()
data_ago = crawling.consensus_crawling_DB_a_month_ago()
# Out:
# Loading page number 1...
# Loading page number 2...
# Loading page number 3...
# Loading page number 4...
# Loading page number 5...
# Loading page number 6...
# Loading page number 7...
# Loading page number 8...
# Loading page number 9...
# Loading page number 10...
# Loading page number 11...
# Loading page number 12...
# Loading page number 13...
# Loading page number 14...
# Loading page number 15...
# Loading page number 16...
# Loading page number 17...
# Loading page number 18...
# Loading page number 19...
# Loading page number 20...
# Loading page number 21...
# Loading page number 22...
# Loading page number 23...
# Loading page number 24...
# Loading page number 25...
# Loading page number 26...
# Loading page number 27...
# Loading page number 28...
# Loading page number 29...
# Loading page number 30...
# Loading page number 31...
# Loading page number 32...
# Loading page number 33...
# Loading page number 34...
# Loading page number 35...
# Loading page number 36...
# Loading page number 37...
# Loading page number 1...
# Loading page number 2...
# Loading page number 3...
# Loading page number 4...
# Loading page number 5...
# Loading page number 6...
# Loading page number 7...
# Loading page number 8...
# Loading page number 9...
# Loading page number 10...
# Loading page number 11...
# Loading page number 12...
# Loading page number 13...
# Loading page number 14...
# Loading page number 15...
# Loading page number 16...
# Loading page number 17...
# Loading page number 18...
# Loading page number 19...
# Loading page number 20...

# %%
## 뉴스개수 증감 factor
def news_num_change(name): 
    
    a = keyword_daily_news_trend(port['종목명'].to_list(), "2022-04-30", "2022-05-31")
    b = a.loc['2022-05-17'][name]
    c = a.loc['2022-05-18'][name]

    return (c-b) / b

# %%
## 뉴스개수 증감 factor
def news_num_change(name): 
    
    a = keyword_daily_news_trend(port['종목명'].to_list(), "2022-04-30", "2022-05-31")
    b = a.loc['2022-05-17'][name]
    c = a.loc['2022-05-18'][name]

    return (c-b) / b

# %%
## 한경컨센서스 센티멘트 factor 점수 df에 추가하기
doc_list_consensus = []
for stockname in port_list:
    doc_list_consensus.append(scoring.consensus_report_titles(stockname, data)) # 포트폴리오 종목별 한경컨센서스 제목 불러 오기

sentiment_score_consensus = hugging_list(doc_list_consensus) # 한경컨센서스 제목 센티멘트 분석

df['snt_consensus_title_score'] = sentiment_score_consensus # df에 한경컨센서스 제목 센티멘트 점수 추가

# %%
df
# Out:
#           수량    weight     price   yet_ret  snt_news_title_score  \
# 종목명
# 셀트리온     130  0.064972  142500.0  0.010638              0.875310
# 삼성전자     222  0.052634   67600.0  0.019608              0.146902
# 신세계       89  0.080846  259000.0  0.007782              0.237314
# 카카오      888  0.259121   83200.0  0.010936              0.207808
# 효성      1000  0.291102   83000.0  0.008505              0.562402
# SK하이닉스   200  0.078913  112500.0  0.018100              0.353932
# KB금융     288  0.058585   58000.0 -0.011925              0.328216
# 대한항공    1123  0.113827   28900.0  0.000000              0.072781
#
#         snt_consensus_title_score
# 종목명
# 셀트리온                     1.291731
# 삼성전자                     0.820775
# 신세계                      0.666271
# 카카오                      0.824686
# 효성                            NaN
# SK하이닉스                   0.734333
# KB금융                     1.094703
# 대한항공                     0.799285

# %%
## achievement ratio df에 추가
achievement_ratio_port = []
for stockname in port_list:
    achievement_ratio_port.append(scoring.achievement_ratio(stockname, data))

df['achievement_ratio'] = achievement_ratio_port

# %%
df
# Out:
#           수량    weight     price   yet_ret  snt_news_title_score  \
# 종목명
# 셀트리온     130  0.064972  142500.0  0.010638              0.875310
# 삼성전자     222  0.052634   67600.0  0.019608              0.146902
# 신세계       89  0.080846  259000.0  0.007782              0.237314
# 카카오      888  0.259121   83200.0  0.010936              0.207808
# 효성      1000  0.291102   83000.0  0.008505              0.562402
# SK하이닉스   200  0.078913  112500.0  0.018100              0.353932
# KB금융     288  0.058585   58000.0 -0.011925              0.328216
# 대한항공    1123  0.113827   28900.0  0.000000              0.072781
#
#         snt_consensus_title_score  achievement_ratio
# 종목명
# 셀트리온                     1.291731           0.678571
# 삼성전자                     0.820775           0.883660
# 신세계                      0.666271           0.681579
# 카카오                      0.824686           0.662948
# 효성                            NaN                NaN
# SK하이닉스                   0.734333           0.783972
# KB금융                     1.094703           0.783784
# 대한항공                     0.799285           0.699758

# %%
## target ratio df 에 추가
target_change_port = []
for stockname in port_list:
    target_change_port.append(scoring.target_change(stockname,data,data_ago))

df['target_change'] = target_change_port

# %%
df
# Out:
#           수량    weight     price   yet_ret  snt_news_title_score  \
# 종목명
# 셀트리온     130  0.064972  142500.0  0.010638              0.875310
# 삼성전자     222  0.052634   67600.0  0.019608              0.146902
# 신세계       89  0.080846  259000.0  0.007782              0.237314
# 카카오      888  0.259121   83200.0  0.010936              0.207808
# 효성      1000  0.291102   83000.0  0.008505              0.562402
# SK하이닉스   200  0.078913  112500.0  0.018100              0.353932
# KB금융     288  0.058585   58000.0 -0.011925              0.328216
# 대한항공    1123  0.113827   28900.0  0.000000              0.072781
#
#         snt_consensus_title_score  achievement_ratio  target_change
# 종목명
# 셀트리온                     1.291731           0.678571            NaN
# 삼성전자                     0.820775           0.883660       0.947368
# 신세계                      0.666271           0.681579       0.950000
# 카카오                      0.824686           0.662948       1.012097
# 효성                            NaN                NaN            NaN
# SK하이닉스                   0.734333           0.783972       0.960937
# KB금융                     1.094703           0.783784       1.027778
# 대한항공                     0.799285           0.699758       1.086842

# %%
## 종토방 댓글 개수 변화율 df에 추가
reply_vol_port = []
for stockname in port_list:
    reply_vol_port.append(scoring.reply_vol(stockname))

df['reply_vol'] = reply_vol_port

# %%
df
# Out:
#           수량    weight     price   yet_ret  snt_news_title_score  \
# 종목명
# 셀트리온     130  0.064972  142500.0  0.010638              0.875310
# 삼성전자     222  0.052634   67600.0  0.019608              0.146902
# 신세계       89  0.080846  259000.0  0.007782              0.237314
# 카카오      888  0.259121   83200.0  0.010936              0.207808
# 효성      1000  0.291102   83000.0  0.008505              0.562402
# SK하이닉스   200  0.078913  112500.0  0.018100              0.353932
# KB금융     288  0.058585   58000.0 -0.011925              0.328216
# 대한항공    1123  0.113827   28900.0  0.000000              0.072781
#
#         snt_consensus_title_score  achievement_ratio  target_change  reply_vol
# 종목명
# 셀트리온                     1.291731           0.678571            NaN  -0.408138
# 삼성전자                     0.820775           0.883660       0.947368   0.136752
# 신세계                      0.666271           0.681579       0.950000  -0.222222
# 카카오                      0.824686           0.662948       1.012097  -0.173913
# 효성                            NaN                NaN            NaN   0.333333
# SK하이닉스                   0.734333           0.783972       0.960937  -0.205607
# KB금융                     1.094703           0.783784       1.027778   1.166667
# 대한항공                     0.799285           0.699758       1.086842   0.904762

# %%
## 뉴스개수 변화율 df에 추가
news_num_change_port = []
for stockname in port_list:
    news_num_change_port.append(news_num_change(stockname))

df['news_num_change'] = news_num_change_port

# %%
df
# Out:
#           수량    weight     price   yet_ret  snt_news_title_score  \
# 종목명
# 셀트리온     130  0.064972  142500.0  0.010638              0.875310
# 삼성전자     222  0.052634   67600.0  0.019608              0.146902
# 신세계       89  0.080846  259000.0  0.007782              0.237314
# 카카오      888  0.259121   83200.0  0.010936              0.207808
# 효성      1000  0.291102   83000.0  0.008505              0.562402
# SK하이닉스   200  0.078913  112500.0  0.018100              0.353932
# KB금융     288  0.058585   58000.0 -0.011925              0.328216
# 대한항공    1123  0.113827   28900.0  0.000000              0.072781
#
#         snt_consensus_title_score  achievement_ratio  target_change  \
# 종목명
# 셀트리온                     1.291731           0.678571            NaN
# 삼성전자                     0.820775           0.883660       0.947368
# 신세계                      0.666271           0.681579       0.950000
# 카카오                      0.824686           0.662948       1.012097
# 효성                            NaN                NaN            NaN
# SK하이닉스                   0.734333           0.783972       0.960937
# KB금융                     1.094703           0.783784       1.027778
# 대한항공                     0.799285           0.699758       1.086842
#
#         reply_vol  news_num_change
# 종목명
# 셀트리온    -0.408138         0.960000
# 삼성전자     0.136752         0.037915
# 신세계     -0.222222         0.147059
# 카카오     -0.173913        -0.040000
# 효성       0.333333        -0.875000
# SK하이닉스  -0.205607         0.070423
# KB금융     1.166667         1.111111
# 대한항공     0.904762        -0.560976

# %% [markdown]
# * 그래프 그리기

# %%
from math import pi
from matplotlib.path import Path
from matplotlib.spines import Spine
from matplotlib.transforms import Affine2D
import matplotlib.pyplot as plt

# %%
for i, row in df[df.columns[4:]].iterrows():
    print(i)
    print('\n')
    print(row)
# Out:
# 셀트리온
#
#
# snt_news_title_score         0.875310
# snt_consensus_title_score    1.291731
# achievement_ratio            0.678571
# target_change                     NaN
# reply_vol                   -0.408138
# news_num_change              0.960000
# Name: 셀트리온, dtype: float64
# 삼성전자
#
#
# snt_news_title_score         0.146902
# snt_consensus_title_score    0.820775
# achievement_ratio            0.883660
# target_change                0.947368
# reply_vol                    0.136752
# news_num_change              0.037915
# Name: 삼성전자, dtype: float64
# 신세계
#
#
# snt_news_title_score         0.237314
# snt_consensus_title_score    0.666271
# achievement_ratio            0.681579
# target_change                0.950000
# reply_vol                   -0.222222
# news_num_change              0.147059
# Name: 신세계, dtype: float64
# 카카오
#
#
# snt_news_title_score         0.207808
# snt_consensus_title_score    0.824686
# achievement_ratio            0.662948
# target_change                1.012097
# reply_vol                   -0.173913
# news_num_change             -0.040000
# Name: 카카오, dtype: float64
# 효성
#
#
# snt_news_title_score         0.562402
# snt_consensus_title_score         NaN
# achievement_ratio                 NaN
# target_change                     NaN
# reply_vol                    0.333333
# news_num_change             -0.875000
# Name: 효성, dtype: float64
# SK하이닉스
#
#
# snt_news_title_score         0.353932
# snt_consensus_title_score    0.734333
# achievement_ratio            0.783972
# target_change                0.960937
# reply_vol                   -0.205607
# news_num_change              0.070423
# Name: SK하이닉스, dtype: float64
# KB금융
#
#
# snt_news_title_score         0.328216
# snt_consensus_title_score    1.094703
# achievement_ratio            0.783784
# target_change                1.027778
# reply_vol                    1.166667
# news_num_change              1.111111
# Name: KB금융, dtype: float64
# 대한항공
#
#
# snt_news_title_score         0.072781
# snt_consensus_title_score    0.799285
# achievement_ratio            0.699758
# target_change                1.086842
# reply_vol                    0.904762
# news_num_change             -0.560976
# Name: 대한항공, dtype: float64

# %%
df[df.columns[4:]].iloc[0].to_list()
# Out:
# [0.8753104615211487,
#  1.2917314171791077,
#  0.6785714285714286,
#  nan,
#  -0.4081381011097411,
#  0.96]

# %%
tmp
# Out:
#         snt_news_title_score  snt_consensus_title_score  achievement_ratio  \
# 종목명
# 셀트리온                0.875310                   1.291731           0.678571
# 삼성전자                0.146902                   0.820775           0.883660
# 신세계                 0.237314                   0.666271           0.681579
# 카카오                 0.207808                   0.824686           0.662948
# 효성                  0.562402                   0.000000           0.000000
# SK하이닉스              0.353932                   0.734333           0.783972
# KB금융                0.328216                   1.094703           0.783784
# 대한항공                0.072781                   0.799285           0.699758
#
#         target_change  reply_vol  news_num_change
# 종목명
# 셀트리온         0.000000  -0.408138         0.960000
# 삼성전자         0.947368   0.136752         0.037915
# 신세계          0.950000  -0.222222         0.147059
# 카카오          1.012097  -0.173913        -0.040000
# 효성           0.000000   0.333333        -0.875000
# SK하이닉스       0.960937  -0.205607         0.070423
# KB금융         1.027778   1.166667         1.111111
# 대한항공         1.086842   0.904762        -0.560976

# %%
tmp
# Out:
#         snt_news_title_score  snt_consensus_title_score  achievement_ratio  \
# 종목명
# 셀트리온                0.875310                   1.291731           0.678571
# 삼성전자                0.146902                   0.820775           0.883660
# 신세계                 0.237314                   0.666271           0.681579
# 카카오                 0.207808                   0.824686           0.662948
# 효성                  0.562402                   0.000000           0.000000
# SK하이닉스              0.353932                   0.734333           0.783972
# KB금융                0.328216                   1.094703           0.783784
# 대한항공                0.072781                   0.799285           0.699758
#
#         target_change  reply_vol  news_num_change
# 종목명
# 셀트리온         0.000000  -0.408138         0.960000
# 삼성전자         0.947368   0.136752         0.037915
# 신세계          0.950000  -0.222222         0.147059
# 카카오          1.012097  -0.173913        -0.040000
# 효성           0.000000   0.333333        -0.875000
# SK하이닉스       0.960937  -0.205607         0.070423
# KB금융         1.027778   1.166667         1.111111
# 대한항공         1.086842   0.904762        -0.560976

# %%
tmp.rename(columns={"snt_news_title_score": "뉴스들 갬성", "snt_consensus_title_score":"애널들 갬성", "achievement_ratio": "적정가 대비 현재주가", "target_change":"전문가들 말바꿈 정도", "reply_vol":"토론방 시끌벅적도", "news_num_change":"기자들 시끌벅적도"})
# Out:
#           뉴스들 갬성    애널들 갬성  적정가 대비 현재주가  전문가들 말바꿈 정도  토론방 시끌벅적도  기자들 시끌벅적도
# 종목명
# 셀트리온    0.875310  1.291731     0.678571     0.000000  -0.408138   0.960000
# 삼성전자    0.146902  0.820775     0.883660     0.947368   0.136752   0.037915
# 신세계     0.237314  0.666271     0.681579     0.950000  -0.222222   0.147059
# 카카오     0.207808  0.824686     0.662948     1.012097  -0.173913  -0.040000
# 효성      0.562402  0.000000     0.000000     0.000000   0.333333  -0.875000
# SK하이닉스  0.353932  0.734333     0.783972     0.960937  -0.205607   0.070423
# KB금융    0.328216  1.094703     0.783784     1.027778   1.166667   1.111111
# 대한항공    0.072781  0.799285     0.699758     1.086842   0.904762  -0.560976

# %%
(len(tmp.index) % 2 ) == 0
# Out:
# True

# %%
def rader_graph (port):

    labels = port.columns[4:]
    num_labels = len(labels)

    tmp = port[labels]
    tmp = tmp.fillna(0)

    tmp.rename(columns={"snt_news_title_score": "뉴스들 갬성", "snt_consensus_title_score":"애널들 갬성", "achievement_ratio": "적정가 대비 현재주가", "target_change":"전문가들 말바꿈 정도", "reply_vol":"토론방 시끌벅적도", "news_num_change":"기자들 시끌벅적도"}, inplace=True)
    labels = tmp.columns.to_list()


    angles = [x/float(num_labels)*(2*pi) for x in range(num_labels)]
    angles += angles[:1]

    my_palette = plt.cm.get_cmap("Set2", len(tmp.index))

    fig = plt.figure(figsize=(15, 27), dpi=200)
    fig.set_facecolor('w')

    idx_num = len(tmp.index)

    if (idx_num % 2) == 0:
        sub_idx_1 = int(idx_num / 2)
        sub_idx_2 = 2

    else:
        sub_idx_1 = int((idx_num + 1) / 2)
        sub_idx_2 = 2

    for i, row in tmp.iterrows():

        idx = tmp.index.to_list().index(i)
        sub_idx_3 = idx + 1

        color = my_palette(idx)


        data = tmp.iloc[idx].to_list()    
        data += data[:1]

        ax = plt.subplot(sub_idx_1, sub_idx_2, sub_idx_3, polar=True)
        ax.set_theta_offset(pi/2)
        ax.set_theta_direction(-1)

        plt.xticks(angles[:-1], labels, fontsize=13)
        ax.tick_params(axis='x', width='major', pad=15)

        ax.set_rlabel_position(0)
        plt.yticks([-2, -1, 0, 1, 2], ['-2', '-1', '0', '1', '2'], fontsize=10)
        plt.ylim(-2,2)

        ax.plot(angles, data, color=color, linewidth=2, linestyle='solid')
        ax.fill(angles, data, color=color, alpha=0.4)

        plt.title(i, size=30, color=color, x=-0.15, y=1.1, ha='center', fontweight='bold')

    plt.tight_layout(pad=5)
    plt.show()

# %%
rader_graph(df)

# %%
labels = df.columns[4:]
num_labels = len(labels)

tmp = df[labels]
tmp = tmp.fillna(0)

angles = [x/float(num_labels)*(2*pi) for x in range(num_labels)]
angles += angles[:1]

my_palette = plt.cm.get_cmap("Set2", len(tmp.index))

fig = plt.figure(figsize=(15, 27), dpi=200)
fig.set_facecolor('w')

idx_num = len(tmp.index)

if (idx_num % 2) == 0:
    sub_idx_1 = int(idx_num / 2)
    sub_idx_2 = 2

else:
    sub_idx_1 = int((idx_num + 1) / 2)
    sub_idx_2 = 2

for i, row in df.iterrows():

    idx = tmp.index.to_list().index(i)
    sub_idx_3 = idx + 1

    color = my_palette(idx)


    data = tmp.iloc[idx].to_list()    
    data += data[:1]

    ax = plt.subplot(sub_idx_1, sub_idx_2, sub_idx_3, polar=True)
    ax.set_theta_offset(pi/2)
    ax.set_theta_direction(-1)

    plt.xticks(angles[:-1], labels, fontsize=13)
    ax.tick_params(axis='x', width='major', pad=15)

    ax.set_rlabel_position(0)
    plt.yticks([-2, -1, 0, 1, 2], ['-2', '-1', '0', '1', '2'], fontsize=10)
    plt.ylim(-2,2)

    ax.plot(angles, data, color=color, linewidth=2, linestyle='solid')
    ax.fill(angles, data, color=color, alpha=0.4)

    plt.title(i, size=20, color=color, x=-0.2, y=1.2, ha='left', fontweight='bold')

plt.tight_layout(pad=5)
plt.show()

# %% [markdown]
# # Wordcloud

# %%
from konlpy.tag import Okt
from PIL import Image
from wordcloud import ImageColorGenerator
from wordcloud import WordCloud
from collections import Counter

# %%
def preprocess(date_from, date_to, keyword_list):
    
    buffer = []

    for keyword in keyword_list:
        key = download_total_title_keyword (date_from, date_to, keyword)
        key = sum(key,[])
        

        key=' '.join(s for s in key)
        buffer.append(key)
    
    
    
    return buffer 

def plot_wordcloud(bodies,weight,score):

    '''글 '''
    '''
    각 종목들의 기사 body들과 포트폴리오 가중치를 인수로 받아 
    가중치만큼 반영하여 빈도수에 가중하여 워드클라우드로 출력
    '''


    weight = np.array(weight)*10000
    
    np.rint(weight)

    buffer=[]
    
    for i,v in enumerate(bodies):
        okt = Okt()
        noun_list = list(okt.nouns(v))
        pos_list = list(okt.pos(v))
        noun_list=[x for x in noun_list if len(x)>1]

        noun_list*= int(weight[i])

        buffer.append(noun_list)
        
    buffer = sum(buffer,[]) # 리스트의 리스트를 하나의 리스트로 전환
        

    dancing_mask = np.array(Image.open('./wordcloud/psy2.jpg').convert("RGBA"))
    sunny_mask = np.array(Image.open('./wordcloud/sunny.jpg').convert("RGBA"))
    sunny_cloudy_mask = np.array(Image.open('./wordcloud/sunny_clouds.jpg').convert("RGBA"))
    cloudy_mask = np.array(Image.open('./wordcloud/cloud2.png').convert("RGBA"))
    rainy_mask = np.array(Image.open('./wordcloud/raindrop.png').convert("RGBA"))

    if score >= 0.9:
        mask = dancing_mask
        
    elif score >= 0.75:
        mask = sunny_mask
        
    elif score >= 0.5:
        mask = sunny_cloudy_mask
        
    elif score >= 0.25:
        mask = cloudy_mask
        
    elif score >= 0:
        mask = rainy_mask
    
    else:
        mask = None
        
    if mask != None:
        wordcloud = WordCloud(font_path='./wordcloud/HANYheadM.ttf',mask=mask,width=800, height=800,background_color='white', color_func=ImageColorGenerator(mask))
    else:
        wordcloud = WordCloud(font_path='./wordcloud/HANYheadM.ttf',mask=mask,width=800, height=800,background_color='white')


    count = Counter(buffer)
    wordcloud = wordcloud.generate_from_frequencies(count)
    array = wordcloud.to_array()

    fig = plt.figure(figsize=(20,20), facecolor='w', dpi=200)
    plt.imshow(array, interpolation='bilinear')
    plt.axis("off")
    plt.show()

    return


def wordcloud_creator_with_keyword (date_from, date_to, keyword_list, weight, score):
    
    '''weight는 포트폴리오 웨이트는 리스트로 들어가야댐, Score는 날씨 정보'''

    buffer = preprocess(date_from, date_to, keyword_list)

    plot_wordcloud(buffer, weight, score)

# %%
df.weight.to_list()
# Out:
# [0.06497184553360211,
#  0.05263403402385282,
#  0.0808456686313124,
#  0.25912139827127545,
#  0.291101926007502,
#  0.07891317271287705,
#  0.058585139422039925,
#  0.11382681539753826]

# %%
wordcloud_creator_with_keyword("2022-05-17", "2022-05-17", df.index.to_list(), df.weight.to_list(), 0.8)
# Out:
# ---------------------------------------------------------------------------
#
# ValueError                                Traceback (most recent call last)
#
# /Users/Sun/Documents/Github/Unstructrued_data_TP/Final Organization/Final_Organization_Module.ipynb Cell 62' in <cell line: 1>()
#
# ----> <a href='vscode-notebook-cell:/Users/Sun/Documents/Github/Unstructrued_data_TP/Final%20Organization/Final_Organization_Module.ipynb#ch0000057?line=0'>1</a> wordcloud_creator_with_keyword("2022-05-17", "2022-05-17", df.index.to_list(), df.weight.to_list(), 0.8)
#
#
#
# /Users/Sun/Documents/Github/Unstructrued_data_TP/Final Organization/Final_Organization_Module.ipynb Cell 60' in wordcloud_creator_with_keyword(date_from, date_to, keyword_list, weight, score)
#
#      <a href='vscode-notebook-cell:/Users/Sun/Documents/Github/Unstructrued_data_TP/Final%20Organization/Final_Organization_Module.ipynb#ch0000056?line=88'>89</a> '''weight는 포트폴리오 웨이트는 리스트로 들어가야댐, Score는 날씨 정보'''
#
#      <a href='vscode-notebook-cell:/Users/Sun/Documents/Github/Unstructrued_data_TP/Final%20Organization/Final_Organization_Module.ipynb#ch0000056?line=90'>91</a> buffer = preprocess(date_from, date_to, keyword_list)
#
# ---> <a href='vscode-notebook-cell:/Users/Sun/Documents/Github/Unstructrued_data_TP/Final%20Organization/Final_Organization_Module.ipynb#ch0000056?line=92'>93</a> plot_wordcloud(buffer, weight, score)
#
#
#
# /Users/Sun/Documents/Github/Unstructrued_data_TP/Final Organization/Final_Organization_Module.ipynb Cell 60' in plot_wordcloud(bodies, weight, score)
#
#      <a href='vscode-notebook-cell:/Users/Sun/Documents/Github/Unstructrued_data_TP/Final%20Organization/Final_Organization_Module.ipynb#ch0000056?line=65'>66</a> else:
#
#      <a href='vscode-notebook-cell:/Users/Sun/Documents/Github/Unstructrued_data_TP/Final%20Organization/Final_Organization_Module.ipynb#ch0000056?line=66'>67</a>     mask = None
#
# ---> <a href='vscode-notebook-cell:/Users/Sun/Documents/Github/Unstructrued_data_TP/Final%20Organization/Final_Organization_Module.ipynb#ch0000056?line=68'>69</a> if mask != None:
#
#      <a href='vscode-notebook-cell:/Users/Sun/Documents/Github/Unstructrued_data_TP/Final%20Organization/Final_Organization_Module.ipynb#ch0000056?line=69'>70</a>     wordcloud = WordCloud(font_path='./wordcloud/HANYheadM.ttf',mask=mask,width=800, height=800,background_color='white', color_func=ImageColorGenerator(mask))
#
#      <a href='vscode-notebook-cell:/Users/Sun/Documents/Github/Unstructrued_data_TP/Final%20Organization/Final_Organization_Module.ipynb#ch0000056?line=70'>71</a> else:
#
#
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %% [markdown]
# # 개판 Sentiment 돌릴거

# %%
OKt(), Hannanum(),

# %% [markdown]
# 키워드

# %% [markdown]
# 키워드

# %%
from konlpy.tag import Hannanum
from config import * # config안의 정보 가져오기
from transformers import pipeline
import re
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, Dense, LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow import keras


np.random.seed(1234)
tf.random.set_seed(1234)

model_review = keras.models.load_model('models/best_model_hannanum_review copy.h5')
model_up_down = keras.models.load_model('models/best_model(Okt) copy.h5')


tokenizer = Tokenizer()
han = Hannanum()
classifier = pipeline('sentiment-analysis', model='snunlp/KR-FinBert-SC')

# %%
a = download_total_title_keyword("2022-05-01", "2022-05-02", "삼성전자")
# Out:
# Downloading data from OpenSearch server
# 2022-05-01 Start!
# ***2022-05-01End!***
# 2022-05-02 Start!
# ***2022-05-02End!***
# Daily Data end!

# %%
len(a)
# Out:
# 205

# %%
len(key_list)
# Out:
# 7

# %%
key_list = list(set(key_list[0]))

# %%
key_list[0]
# Out:
# '■삼성전자, 멀어지는 시스템반도체 1위\nTSMC·퀄컴 등 시장 확대와 대조\nM&A전문가 영입·선단공정 확보\n분위기 쇄신 박차로 돌파구 모색\n[서울경제]\n삼성전자의 ‘2030년 시스템반도체 1위’ 도전이 쉽지 않다.\n핵심 애플리케이션 프로세서(AP) ‘엑시노스’ 설계부터 파운드리(칩 위탁 생산) 사업까지 사업 확대가 좀처럼 진전되지 못하고 있어서다. 경쟁사의 야성적인 사업 진출과 기술 개발 움직임도 간과할 수 없다. 삼성전자는 고객사 확보와 신규 인수합병(M&A), 기술 초격차에서 돌파구를 찾기 위해 다양한 대책을 세우고 있다.\n2019년 4월 30일 이재용 삼성전자 부회장은 삼성전자 화성캠퍼스에서 열린 선포식에서 “메모리에 이어 파운드리를 포함한 시스템반도체 분야에서도 확실히 1등을 하도록 하겠다”고 선언했다. 당시 행사에 참석했던 문재인 대통령은 “우리의 목표는 분명하다. 2030년까지 시스템반도체 파운드리(위탁 생산) 분야 세계 1위를 달성하는 것”이라고 화답했다.\n3년이 지난 지금 각종 시장 데이터는 삼성전자의 도전이 녹록지 않음을 보여주고 있다.\n시장조사 업체 스트래티지애널리틱스(SA)에 따르면 삼성전자 모바일 AP 시장점유율은 2019년 12.0%에서 지난해 6.6%로 하락했다. 이 분야 강자 퀄컴의 점유율은 2019년 34.8%에서 지난해 37.7%로, 애플은 22.9%에서 26%로 늘어난 것과 대조적이다.\n파운드리 사업에서도 삼성전자의 점유율은 2019년부터 18% 안팎에서 정체된 모양새다. 업계 1위 TSMC는 꾸준히 50% 이상을 유지하면서 점유율을 늘려나가는 추세다. 후발 경쟁자 진입도 매섭다. 지난해 3월 파운드리 사업 재개를 선언하며 업계를 놀라게 한 인텔도 최근 1분기 실적 발표회에서 파운드리 사업부 매출만 분리한 실적(2억 8300만 달러)을 처음 공개하며 존재감을 알렸다.\n이에 삼성 시스템반도체 사업을 향한 우려 섞인 루머가 나오고 있다. 지난달 28일 열렸던 삼성전자 1분기 실적 발표회에서는 파운드리 고객사 이탈에 관한 질문이 나왔다. 강문수 삼성전자 부사장은 이에 대해 “고객사 수요가 생산능력 이상으로 견조하고 최근 시장의 우려가 과도하다”고 반박했다.\n삼성전자는 선단 공정 확보, 생산능력 확장, M&A 전문가 영입 등으로 분위기 쇄신에 박차를 가하고 있다. 삼성전자는 1분기 실적 발표회를 통해 상반기 내 3나노(㎚·10억분의 1) 게이트올어라운드(GAA) 공정 양산을 세계 최초로 시작한다는 계획에 변함이 없음을 밝혔다.\n또 사상 초유의 반도체 장비 공급 부족 현상에도 하반기 평택 3공장 파운드리 라인 준비, 평택 4공장과 테일러 파운드리 기초 공사 등을 통해 생산능력을 확보해 나갈 방침이다. 엑시노스 AP 사업의 경우 LSI사업부 내 칩 설계 인력을 차세대 엑시노스 개발에 집중시키는 방침을 세운 것으로 알려진다.\n반도체 M&A 전문가를 영입한 점도 눈에 띈다. 최근 삼성전자는 뱅크오브아메리카(BoA) 출신 반도체 분야 M&A 전문가 마코 치사리를 영입했다. 마코 치사리는 인피니언의 사이프러스 인수(약 100억 달러 규모) 등 대형 반도체 M&A를 주도한 경험이 있다.'

# %%
# result = classifier(key_list[0:100])

# for i in range(0, len(key_list[0:100])-1):
#     print(f"이 뉴스는 {round(result[i]['score'] * 100, 2)}% 확률로 {result[i]['label']} 입니다.")
#     print(f"제목 : {key_list[i]}\n")

# %%
key_list[0][0][0]
# Out:
# '‘셀트리온’ 집중 매수, 대차잔고 증가[외인이 담은 바이오]'

# %%
def hugging_list (doc_list):

    neutral_num = 0
    positive_num = 0
    negative_num = 0

    for i in doc_list:
        result = classifier(i[0])

        for k in range(0, len(result)-1):
            print(f"이 뉴스는 {round(result[k]['score'] * 100, 2)}% 확률로 {result[k]['label']} 입니다.")
            print(f"제목 : {i[k]}\n")

            if result[i]['label'] == 'neutral':
                neutral_num += 1
            elif result[i]['label'] == 'positive':
                positive_num += 1
            else:
                negative_num += 1


    print(f"neutral : {neutral_num}")
    print(f"positive : {positive_num}")
    print(f"negative : {negative_num}")

# %%
hugging_list(key_list)
# Out:
# neutral : 0
# positive : 0
# negative : 0

# %%
'''불용어 정리'''
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

# %%
#model = keras.models.load_model("./models/best_model(Okt).h5")
#okt = Okt()


def sentiment_predict(new_sentence, model_name):
    new_sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','', new_sentence)
    new_sentence = han.morphs(new_sentence) # 토큰화
    new_sentence = [word for word in new_sentence if not word in stopwords] # 불용어 제거
    encoded = tokenizer.texts_to_sequences([new_sentence]) # 정수 인코딩
    pad_new = pad_sequences(encoded, maxlen = 50) # 패딩
    score = float(model_name.predict(pad_new)) # 예측
    if(score > 0.65):
        print("{:.2f}% 확률로 긍정적입니다.\n".format(score * 100))
    elif (score >0.40):
        print("{:.2f}% 확률로 중립적입니다.\n".format(score * 100))
    else:
        print("{:.2f}% 확률로 부정적입니다.\n".format((1 - score) * 100))

# %%
sentiment_predict("정말 재미있어요", model_review)
# Out:
# 59.35% 확률로 중립적입니다.
# 2022-06-11 02:58:10.973160: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-06-11 02:58:11.030872: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %%
sentiment_predict(key_list[0][0][0], model_review)
# Out:
# 59.35% 확률로 중립적입니다.

# %%
sentiment_predict(key_list[0][0][1], model_review)
# Out:
# 59.35% 확률로 중립적입니다.

# %%
new_sentence = "2000명 몰렸다…삼성전자 '갤럭시 팬파티' 성료"
new_sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','', new_sentence)
new_sentence = han.morphs(new_sentence) # 토큰화
new_sentence
#new_sentence = [word for word in new_sentence if not word in stopwords]
# Out:
# ['명', '몰렸다삼성전자', '갤럭시', '팬파티', '성료']

# %%
encoded = tokenizer.texts_to_sequences([new_sentence]) # 정수 인코딩
pad_new = pad_sequences(encoded, maxlen = 30) # 패딩
score = float(model_review.predict(pad_new)) # 예측
score
# Out:
# 0.611977756023407

# %%
model_review.predict(['삼성전자 상반기 C랩 스핀오프 론칭데이'])
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, None) for input KerasTensor(type_spec=TensorSpec(shape=(None, None), dtype=tf.float32, name='embedding_input'), name='embedding_input', description="created by layer 'embedding_input'"), but it was called on an input with incompatible shape (None,).
# ---------------------------------------------------------------------------
#
# ValueError                                Traceback (most recent call last)
#
# /Users/Sun/Documents/Github/Unstructrued_data_TP/Final Organization/Final_Organization_Module.ipynb Cell 62' in <cell line: 1>()
#
# ----> <a href='vscode-notebook-cell:/Users/Sun/Documents/Github/Unstructrued_data_TP/Final%20Organization/Final_Organization_Module.ipynb#ch0000071?line=0'>1</a> model_review.predict(['삼성전자 상반기 C랩 스핀오프 론칭데이'])
#
#
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/NLP/lib/python3.8/site-packages/keras/utils/traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#
#      65 except Exception as e:  # pylint: disable=broad-except
#
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ---> 67   raise e.with_traceback(filtered_tb) from None
#
#      68 finally:
#
#      69   del filtered_tb
#
#
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/NLP/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py:1147, in func_graph_from_py_func.<locals>.autograph_handler(*args, **kwargs)
#
#    1145 except Exception as e:  # pylint:disable=broad-except
#
#    1146   if hasattr(e, "ag_error_metadata"):
#
# -> 1147     raise e.ag_error_metadata.to_exception(e)
#
#    1148   else:
#
#    1149     raise
#
#
#
# ValueError: in user code:
#
#
#
#     File "/opt/homebrew/Caskroom/miniforge/base/envs/NLP/lib/python3.8/site-packages/keras/engine/training.py", line 1801, in predict_function  *
#
#         return step_function(self, iterator)
#
#     File "/opt/homebrew/Caskroom/miniforge/base/envs/NLP/lib/python3.8/site-packages/keras/engine/training.py", line 1790, in step_function  **
#
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#
#     File "/opt/homebrew/Caskroom/miniforge/base/envs/NLP/lib/python3.8/site-packages/keras/engine/training.py", line 1783, in run_step  **
#
#         outputs = model.predict_step(data)
#
#     File "/opt/homebrew/Caskroom/miniforge/base/envs/NLP/lib/python3.8/site-packages/keras/engine/training.py", line 1751, in predict_step
#
#         return self(x, training=False)
#
#     File "/opt/homebrew/Caskroom/miniforge/base/envs/NLP/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#
#         raise e.with_traceback(filtered_tb) from None
#
#     File "/opt/homebrew/Caskroom/miniforge/base/envs/NLP/lib/python3.8/site-packages/keras/engine/input_spec.py", line 214, in assert_input_compatibility
#
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" '
#
#
#
#     ValueError: Exception encountered when calling layer "sequential" (type Sequential).
#
#
#
#     Input 0 of layer "lstm" is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 100)
#
#
#
#     Call arguments received:
#
#       • inputs=tf.Tensor(shape=(None,), dtype=string)
#
#       • training=False
#
#       • mask=None

# %%
key_list[0][0]
# Out:
# '삼성전자 상반기 C랩 스핀오프 론칭데이'

# %%
for i in key_list[0][10:40]:
    sentiment_predict(i, model_name=model_review)
# Out:
# 0.611977756023407
# 61.20% 확률로 긍정적입니다.
# AI로 온라인 시험 부정 잡는다..삼성이 지원하는 사내벤처는?
#
# 0.611977756023407
# 61.20% 확률로 긍정적입니다.
# 삼성전자, hy·삼성카드와 '비스포크 큐커' 할인행사
#
# 0.611977756023407
# 61.20% 확률로 긍정적입니다.
# "AI가 시험 감독"…삼성전자, 사내벤처 2곳 '픽'
#
# 0.611977756023407
# 61.20% 확률로 긍정적입니다.
# 삼성전자, hy와 함께 '우리집 전자레인지, 큐커로 교체' 캠페인
#
# 0.611977756023407
# 61.20% 확률로 긍정적입니다.
# 삼성전자, hy와 함께 '우리집 전자레인지, 큐커로 교체' 캠페인
#
# 0.611977756023407
# 61.20% 확률로 긍정적입니다.
# 삼성전자, hy와 함께 '우리집 전자레인지, 큐커로 교체' 캠페인
#
# 0.611977756023407
# 61.20% 확률로 긍정적입니다.
# 삼성전자, hy와 함께 '우리집 전자레인지, 큐커로 교체' 캠페인
#
# 0.611977756023407
# 61.20% 확률로 긍정적입니다.
# 삼성전자, '에듀테크' 관련 C랩 과제 2개 스타트업 창업 지원
#
# 0.611977756023407
# 61.20% 확률로 긍정적입니다.
# 삼성전자, '에듀테크' 관련 C랩 과제 2개 스타트업 창업 지원
#
# 0.611977756023407
# 61.20% 확률로 긍정적입니다.
# 韓 반도체, “공급망 재편서 살아남으려면 美 동맹 참여해야”
#
# 0.611977756023407
# 61.20% 확률로 긍정적입니다.
# 삼성전자, `우리집 전자레인지, 큐커로 교체해요` 2차 캠페인 진행…hy와 협업
#
# 0.611977756023407
# 61.20% 확률로 긍정적입니다.
# ‘지역화폐 지원’ 삼성페이, 지역경제 활성화 나선다
#
# 0.611977756023407
# 61.20% 확률로 긍정적입니다.
# 삼성전자 파운드리 출범 5년…공존하는 '기회와 위기'
#
# 0.611977756023407
# 61.20% 확률로 긍정적입니다.
# 삼성전자, '에듀테크' 관련 C랩 과제 2개 스타트업 창업 지원
#
# 0.611977756023407
# 61.20% 확률로 긍정적입니다.
# "三電, 이재용 부회장 빈자리 크다"…커지는 사면복권 목소리
#
# 0.611977756023407
# 61.20% 확률로 긍정적입니다.
# 삼성전자, 에듀테크 관련 C랩 과제 2개 스타트업 창업 지원
#
# 0.611977756023407
# 61.20% 확률로 긍정적입니다.
# 에버랜드에 모인 '갤럭시 찐팬들'…갤S22 팬파티 현장 컴백 '성공적'
#
# 0.611977756023407
# 61.20% 확률로 긍정적입니다.
# 삼성전자-hy,  '우리집 전자레인지, 큐커로 교체' 캠페인
#
# 0.611977756023407
# 61.20% 확률로 긍정적입니다.
# 삼성전자-hy "비스포크 큐커 약정 구매하고 혜택 받아요"
#
# 0.611977756023407
# 61.20% 확률로 긍정적입니다.
# 우리 집 전자레인지, 비스포크 큐커로 바꿔볼까
#
# 0.611977756023407
# 61.20% 확률로 긍정적입니다.
# '재벌 사면' MB 역대 최다…文, 이재용 '사법 족쇄' 결단은 [뉴스원샷]
#
# 0.611977756023407
# 61.20% 확률로 긍정적입니다.
# 가석방 신세에 갇힌 삼성…文 ‘이재용 사면’ 진짜 할까
#
# 0.611977756023407
# 61.20% 확률로 긍정적입니다.
# “반도체망 2025년 재편… 한국, 美동맹 참여를”
#
# 0.611977756023407
# 61.20% 확률로 긍정적입니다.
# 바이든, 삼성 반도체공장 찾나… “미국 ‘반도체 동맹’에 참여 필요”
#
# 0.611977756023407
# 61.20% 확률로 긍정적입니다.
# 이재용 사면·尹정부 출범·바이든 평택 방문…삼성 운명이 갈린다
#
# 0.611977756023407
# 61.20% 확률로 긍정적입니다.
# 삼성 '2030 시스템반도체 1위' 선포 3년…점유율은 오히려 하락
#
# 0.611977756023407
# 61.20% 확률로 긍정적입니다.
# '성공을 향해'
#
# 0.611977756023407
# 61.20% 확률로 긍정적입니다.
# 2000명 몰렸다…삼성전자 '갤럭시 팬파티' 성료
#
# 0.611977756023407
# 61.20% 확률로 긍정적입니다.
# "거북목 고치는 AI"…삼성전자, 에듀테크 스타트업 2곳 스핀오프
#
# 0.611977756023407
# 61.20% 확률로 긍정적입니다.
# 삼성전자, hy와 '전자레인지, 큐커로 교체' 두번째 캠페인

# %%
for i in key_list[0][10:40]:
    sentiment_predict(i, model_name=model_up_down)
# Out:
# 50.96% 확률로 부정적입니다.
# AI로 온라인 시험 부정 잡는다..삼성이 지원하는 사내벤처는?
#
# 50.96% 확률로 부정적입니다.
# 삼성전자, hy·삼성카드와 '비스포크 큐커' 할인행사
#
# 50.96% 확률로 부정적입니다.
# "AI가 시험 감독"…삼성전자, 사내벤처 2곳 '픽'
#
# 50.96% 확률로 부정적입니다.
# 삼성전자, hy와 함께 '우리집 전자레인지, 큐커로 교체' 캠페인
#
# 50.96% 확률로 부정적입니다.
# 삼성전자, hy와 함께 '우리집 전자레인지, 큐커로 교체' 캠페인
#
# 50.96% 확률로 부정적입니다.
# 삼성전자, hy와 함께 '우리집 전자레인지, 큐커로 교체' 캠페인
#
# 50.96% 확률로 부정적입니다.
# 삼성전자, hy와 함께 '우리집 전자레인지, 큐커로 교체' 캠페인
#
# 50.96% 확률로 부정적입니다.
# 삼성전자, '에듀테크' 관련 C랩 과제 2개 스타트업 창업 지원
#
# 50.96% 확률로 부정적입니다.
# 삼성전자, '에듀테크' 관련 C랩 과제 2개 스타트업 창업 지원
#
# 50.96% 확률로 부정적입니다.
# 韓 반도체, “공급망 재편서 살아남으려면 美 동맹 참여해야”
#
# 50.96% 확률로 부정적입니다.
# 삼성전자, `우리집 전자레인지, 큐커로 교체해요` 2차 캠페인 진행…hy와 협업
#
# 50.96% 확률로 부정적입니다.
# ‘지역화폐 지원’ 삼성페이, 지역경제 활성화 나선다
#
# 50.96% 확률로 부정적입니다.
# 삼성전자 파운드리 출범 5년…공존하는 '기회와 위기'
#
# 50.96% 확률로 부정적입니다.
# 삼성전자, '에듀테크' 관련 C랩 과제 2개 스타트업 창업 지원
#
# 50.96% 확률로 부정적입니다.
# "三電, 이재용 부회장 빈자리 크다"…커지는 사면복권 목소리
#
# 50.96% 확률로 부정적입니다.
# 삼성전자, 에듀테크 관련 C랩 과제 2개 스타트업 창업 지원
#
# 50.96% 확률로 부정적입니다.
# 에버랜드에 모인 '갤럭시 찐팬들'…갤S22 팬파티 현장 컴백 '성공적'
#
# 50.96% 확률로 부정적입니다.
# 삼성전자-hy,  '우리집 전자레인지, 큐커로 교체' 캠페인
#
# 50.96% 확률로 부정적입니다.
# 삼성전자-hy "비스포크 큐커 약정 구매하고 혜택 받아요"
#
# 50.96% 확률로 부정적입니다.
# 우리 집 전자레인지, 비스포크 큐커로 바꿔볼까
#
# 50.96% 확률로 부정적입니다.
# '재벌 사면' MB 역대 최다…文, 이재용 '사법 족쇄' 결단은 [뉴스원샷]
#
# 50.96% 확률로 부정적입니다.
# 가석방 신세에 갇힌 삼성…文 ‘이재용 사면’ 진짜 할까
#
# 50.96% 확률로 부정적입니다.
# “반도체망 2025년 재편… 한국, 美동맹 참여를”
#
# 50.96% 확률로 부정적입니다.
# 바이든, 삼성 반도체공장 찾나… “미국 ‘반도체 동맹’에 참여 필요”
#
# 50.96% 확률로 부정적입니다.
# 이재용 사면·尹정부 출범·바이든 평택 방문…삼성 운명이 갈린다
#
# 50.96% 확률로 부정적입니다.
# 삼성 '2030 시스템반도체 1위' 선포 3년…점유율은 오히려 하락
#
# 50.96% 확률로 부정적입니다.
# '성공을 향해'
#
# 50.96% 확률로 부정적입니다.
# 2000명 몰렸다…삼성전자 '갤럭시 팬파티' 성료
#
# 50.96% 확률로 부정적입니다.
# "거북목 고치는 AI"…삼성전자, 에듀테크 스타트업 2곳 스핀오프
#
# 50.96% 확률로 부정적입니다.
# 삼성전자, hy와 '전자레인지, 큐커로 교체' 두번째 캠페인

# %%
하이아아하이아히아히아아아아
